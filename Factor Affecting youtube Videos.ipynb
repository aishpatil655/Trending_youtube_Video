# %% [markdown]
# <div id="Introduction">
# <h1 style="background:black;padding:5%">
#     <span style="color:red"> Factor Affecting</span><span style="color:white"> Trending Video</span><span style="color:red"> On Youtube. </span>
#     <img style="width:50px;height:50px; top-padding:3%; background:white" src="./youtube.svg">
# </h1>
# </div>

# %% [markdown]
# ## Youtube is a online video sharing and social media platform, headquatered in California, United States. Accessable Worldwide, It was launched on February 14, 2005 by Jawed Karim, Steve Chen and Chad Hurley. Its parent company is Google and is the second most visited website just after google search. It has over 2.5 billion monthlty active user, who watch around 1 billion hours of video every day..
#
# <h2 style="color:red">continue this and plz relate this to video and our analisys.. </h2>
#
# ***

# %% [markdown]
# <a id="ProjectAim"></a>
# ## Problem Statement!!!!

# %% [markdown]
# The aim of this research project is to investigate and analyse the key factor influencing the trending videos on one of the most popular and most visited video sharing platform, Youtube.
# With such a dynamic and competitive landscape of online content and content creation, understanding the variables that contribute to a video's popularity is essential for content creators, marketers, and platform algorithms.By diving into the diverse dimensions of video content, engagement metrics, this study seeks to unveil patterns and correlations that underlie the success of YouTube videos in trending categories. Through a comprehensive examination, the project aims to provide insights that can empower content creators to optimize their strategies and enhance the overall comprehension of video trends within the YouTube platform.
#
# The study is split up into four main objective
# * How does factor like description, tags and title effect trending of videos!!!!
# * Ob2
# * Ob3
# * Ob4

# %% [markdown]
# <a id="Table"></a>
# # Table of Content
# * [Introduction](#Introduction)
# * [Problem Statement](#ProjectAim)
#     * [How does factor like description, tags and title effect trending of videos!!!!](#obj1)
#     * [Objective 2](#obj2)
#     * [Objective 3](#obj3)
#     * [Objective 4](#obj4)
# * [Table of Content](#Table)
# * [Importing modules](#importm)
# * [Importing DataSet](#importD)
#     * [Importing video dataset (C.S.V)](#csvData)
#     * [Importing category dataset (JSON)](#jsonData)
# * [Common methods](#common)
# * [Exploratory Data Analysis (E.D.A)](#eda)
#     * [Video dataset EDA](#edavideo)
#     * [Category dataset EDA](#edacat)
# * [Objective 1 : How does factor like description, tags and title effect trending of videos!!!!](#obj1)
#     * [.. make sub objective if required](#obj1a)
# * [Objective 2](#obj2)
#     * [.. make sub objective if required](#obj2a)
# * [Objective 3](#obj3)
#     * [.. make sub objective if required](#obj3a)
# * [Objective 4](#obj4)
#     * [.. make sub objective if required](#obj4a)
# * [Conclusion](#conclusion)

# %% [markdown]
# <a id="importm"> </a>
# ## Importing required modules

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
from wordcloud import WordCloud
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\aishp\OneDrive\Desktop\CW3\Trending_youtube_Video\Factor Affecting youtube Videos.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Desktop/CW3/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Desktop/CW3/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Desktop/CW3/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> from wordcloud import WordCloud
#       <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Desktop/CW3/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> import warnings
#       <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Desktop/CW3/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> warnings.simplefilter(action='ignore', category=FutureWarning)
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# <a id="importD"></a>
# ## Importing Data

# %% [markdown]
# * The sourge of the data was Kaggle, one of the most popular data science competition platform and online community of data scientists and machine learning practitioners under Google LLC.
# * The data we are targeting is "Trending YouTube Video Statistics" This dataset is a daily record of the top trending YouTube videos.
# * MetaData of DataSet
#     * The data is segrated into two source a comma seperated values (c.s.v) and a json.
#     * The csv contain video records while json contain details of category of these videos.
#     * The data contain 40K+ record of trending videos in Canada over the span of two years!!
#     * With 40K+ rows the data also contain 16 columns including but not limited to title, publish time, views, like, dislike.
#     * The json file contain 31 categories with nested json with each category details.

# %% [markdown]
# <a id="csvData"></a>
# ### Importing video dataset (C.S.V)

# %%
videoDF = pd.read_csv("../archive/CAvideos.csv")
videoDF.head(5)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  I know it's been a while since we did this sho...
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...

# %% [markdown]
# <a id="jsonData"></a>
# ### Importing category dataset (JSON)

# %%
categoryDf = pd.read_json("../archive/CA_category_id.json")
categoryDf.head(5)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %% [markdown]
# <a id="common"></a>
# ## Common Methods

# %%
#### ADD Commmon methods here!!!!!

# %%
# method to print Json Object in readable format.. 
def printJsonObject(obj):
    line_list = obj.split("\n")
    for line in line_list:
        print(line)

# %%
# method to get category
def getCategoryFromJson(data):
    category = {}
    for i, row in data.iterrows():
        tempdict = dict(row)
        category[tempdict["items"]["id"]]= tempdict["items"]["snippet"]["title"]
    return category

# %%
# method to get combine dataFrames 
def appendCategoryToDataFrame(dataFrame,category):
    tempList = []
    for i,row in dataFrame.iterrows():
        if str(row["category_id"]) in category.keys():
            tempList.append(category[str(row["category_id"])])
        else :
            tempList.append(None)
    dataFrame["category_name"] = tempList
    return dataFrame

# %% [markdown]
# <a id="eda"></a>
# ## Exploratory Data Analysis (E.D.A)

# %% [markdown]
# <a id="edavideo"></a>
# ### Video Dataset EDA

# %%
videoDF.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
videoDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
#  14  video_error_or_removed  40881 non-null  bool
#  15  description             39585 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
videoDF.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %% [markdown]
# <a id="edacat"></a>
# ### Category Dataset EDA

# %%
categoryDf.columns
# Out:
# Index(['kind', 'etag', 'items'], dtype='object')

# %%
categoryDf.describe()
# Out:
#                                      kind  \
# count                                  31
# unique                                  1
# top     youtube#videoCategoryListResponse
# freq                                   31
#
#                                                      etag  \
# count                                                  31
# unique                                                  1
# top     "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# freq                                                   31
#
#                                                     items
# count                                                  31
# unique                                                 31
# top     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# freq                                                    1

# %%
categoryDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kind    31 non-null     object
#  1   etag    31 non-null     object
#  2   items   31 non-null     object
# dtypes: object(3)
# memory usage: 872.0+ bytes

# %%
## Exploring an complete json item in category dataset
output = json.dumps(categoryDf.iloc[0]["items"],indent=1)
printJsonObject(output)
# Out:
# {
#  "kind": "youtube#videoCategory",
#  "etag": "\"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ\"",
#  "id": "1",
#  "snippet": {
#   "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
#   "title": "Film & Animation",
#   "assignable": true
#  }
# }

# %% [markdown]
# <a id="obj1"></a>
# ## Objective 1 : How does factor like description, tags and title effect trending of videos!!!!

# %%
## Making copy of original dataframe
videoDFCP = videoDF.copy()

# %%
# getting complete Df after adding category to df
getCategoryJson = getCategoryFromJson(categoryDf)
videoCompleteDF = appendCategoryToDataFrame(videoDFCP,getCategoryJson)
videoCompleteDF.head(5)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description  category_name
# 0  Eminem's new track Walk on Water ft. Beyoncé i...          Music
# 1  STill got a lot of packages. Probably will las...         Comedy
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...         Comedy
# 3  I know it's been a while since we did this sho...  Entertainment
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...          Music

# %% [markdown]
# ### Most Common Tags used across Trending Videos!!

# %%
## Word Frequency of tags and sorted in decending order
tagsDictionary = {}
for i,row in videoCompleteDF.iterrows():
    for tag in row["tags"].split('|'):
        if tag in tagsDictionary:
            tagsDictionary[tag] += 1
        else:
            tagsDictionary[tag] = 1
sortedDict = dict(sorted(tagsDictionary.items(), key=lambda x:x[1], reverse=True))
sortedDict
# Out:
# {'"funny"': 3383,
#  '[none]': 2385,
#  '"comedy"': 2378,
#  '"news"': 1343,
#  '"2018"': 1106,
#  '"video"': 1025,
#  '"politics"': 1005,
#  '"humor"': 959,
#  '"review"': 907,
#  '"food"': 899,
#  '"reaction"': 853,
#  '"music"': 837,
#  '"talk show"': 757,
#  '"interview"': 750,
#  '"family friendly"': 746,
#  '"2017"': 741,
#  '"comedian"': 729,
#  '"funny videos"': 648,
#  '"donald trump"': 646,
#  '"trump"': 635,
#  '"News"': 634,
#  '"react"': 633,
#  '"television"': 621,
#  '"how to"': 589,
#  '"science"': 583,
#  '"Donald Trump"': 583,
#  '"entertainment"': 579,
#  '"basketball"': 579,
#  '"sports"': 571,
#  '"jokes"': 569,
#  '"hollywood"': 543,
#  '"podcast"': 543,
#  '"celebrity"': 543,
#  '"movie"': 543,
#  '"show"': 538,
#  '"family"': 522,
#  '"game"': 517,
#  '"Entertainment"': 516,
#  '"Comedy"': 515,
#  '"animation"': 502,
#  '"celebrities"': 501,
#  '"cooking"': 499,
#  '"rap"': 492,
#  '"funny video"': 488,
#  '"tv"': 483,
#  '"challenge"': 476,
#  '"vlog"': 471,
#  '"hilarious"': 470,
#  '"best"': 463,
#  '"Politics"': 458,
#  '"trailer"': 458,
#  '"fun"': 457,
#  '"new"': 455,
#  '"kids"': 453,
#  '"clip"': 450,
#  '"movies"': 447,
#  '"Funny"': 444,
#  '"drama"': 426,
#  '"hip hop"': 425,
#  '"Trump"': 418,
#  '"NBC"': 417,
#  '"highlights"': 407,
#  '"late night"': 388,
#  '"breaking news"': 385,
#  '"top 10"': 384,
#  '"Drama"': 377,
#  '"official"': 372,
#  '"nba"': 370,
#  '"love"': 366,
#  '"fine brothers entertainment"': 366,
#  '"CNN"': 365,
#  '"fine brothers"': 364,
#  '"thefinebros"': 361,
#  '"sketch"': 360,
#  '"live"': 356,
#  '"Canada"': 355,
#  '"FBE"': 353,
#  '"games"': 352,
#  '"humour"': 343,
#  '"film"': 342,
#  '"investigation"': 338,
#  '"recipe"': 337,
#  '"chef"': 336,
#  '"tutorial"': 329,
#  '"joke"': 327,
#  '"kid friendly"': 326,
#  '"music video"': 323,
#  '"Rap"': 321,
#  '"watch"': 319,
#  '"diy"': 318,
#  '"unboxing"': 317,
#  '"satire"': 317,
#  '"famous"': 315,
#  '"youtube"': 312,
#  '"meme"': 310,
#  '"Pop"': 306,
#  '"Trailer"': 304,
#  '"logan paul"': 302,
#  '"kids react"': 298,
#  '"CBS"': 297,
#  '"technology"': 296,
#  '"kitchen"': 296,
#  '"elders react"': 294,
#  '"parody"': 291,
#  '"punjabi songs"': 291,
#  '"sp:vl=en-US"': 289,
#  '"viral"': 289,
#  '"teens react"': 288,
#  '"NBC TV"': 287,
#  '"comedic"': 286,
#  '"celeb"': 285,
#  '"gaming"': 284,
#  '"vs"': 284,
#  '"gameplay"': 284,
#  '"christmas"': 284,
#  '"current events"': 282,
#  '"president trump"': 282,
#  '"conspiracy"': 278,
#  '"celebrity news"': 278,
#  '"police"': 276,
#  '"makeup"': 276,
#  '"try not to laugh"': 275,
#  '"beauty"': 275,
#  '"nba highlights"': 275,
#  '"host"': 274,
#  '"promo"': 272,
#  '"Music"': 271,
#  '"reviews"': 270,
#  '"compilation"': 269,
#  '"sp:ty=high"': 267,
#  '"punjabi"': 263,
#  '"fine bros"': 261,
#  '"education"': 261,
#  '"punjabi music"': 260,
#  '"latest punjabi songs 2018"': 260,
#  'rhett and link': 257,
#  '"travel"': 255,
#  '"laugh"': 253,
#  '"Stephen Colbert"': 252,
#  '"talk"': 251,
#  '"fail"': 249,
#  '"reactions"': 249,
#  '"fashion"': 249,
#  '"learn"': 249,
#  'nba': 248,
#  '"instagram"': 244,
#  '"finebros"': 243,
#  '"india"': 243,
#  '"DIY"': 243,
#  '"game highlights"': 240,
#  '"space"': 238,
#  '"memes"': 238,
#  '"jake paul"': 236,
#  '"animated"': 235,
#  '"cleveland cavaliers"': 232,
#  '"talent"': 229,
#  '"play"': 229,
#  '"us news"': 229,
#  '"highlight"': 228,
#  '"liberal"': 226,
#  '"reddit"': 226,
#  '"TV"': 225,
#  '"Television"': 224,
#  'BuzzFeed': 224,
#  '"crazy"': 222,
#  '"rhett"': 222,
#  '"cavaliers"': 222,
#  '"link"': 221,
#  '"facebook"': 219,
#  '"mythical"': 218,
#  '"James Corden"': 218,
#  '"daily"': 217,
#  '"punjabi latest songs"': 217,
#  '"Colbert"': 217,
#  '"murder"': 216,
#  '"amazing"': 216,
#  '"health"': 216,
#  '"challenges"': 216,
#  '"MSNBC"': 215,
#  '"world"': 215,
#  '"future"': 215,
#  '"cook"': 215,
#  '"lol"': 214,
#  '"tricks"': 214,
#  '"Gordon Ramsay"': 214,
#  '"internet"': 213,
#  '"h3h3"': 212,
#  '"latest punjabi songs"': 212,
#  '"house"': 212,
#  'Gordon': 212,
#  '"disney"': 211,
#  '"latest"': 210,
#  '"football"': 209,
#  '"Ramsay"': 208,
#  '"lebron james"': 207,
#  '"Ramsey"': 207,
#  '"for the first time"': 207,
#  '"fails"': 206,
#  '"mystery"': 206,
#  '"awards"': 206,
#  '"paul"': 205,
#  '"snl"': 204,
#  '"videos"': 203,
#  '"animals"': 203,
#  '"plays"': 202,
#  '"Tutorial"': 202,
#  '"culture"': 202,
#  '"daytime"': 202,
#  '"battle"': 202,
#  '"President Trump"': 201,
#  '"cute"': 201,
#  '"women"': 200,
#  '"song"': 200,
#  '"Chef Ramsay"': 199,
#  '"adventure"': 198,
#  '"Late Late Show"': 198,
#  '"top 5"': 195,
#  '"Corden"': 195,
#  '"video games"': 194,
#  '"scary"': 194,
#  '"the"': 193,
#  '"lyrics"': 192,
#  '"crime patrol"': 192,
#  '"world news"': 192,
#  '"h3h3productions"': 191,
#  '"iphone"': 191,
#  '"facts"': 191,
#  '"to"': 191,
#  '"makeup tutorial"': 191,
#  '"youtubers react"': 190,
#  '"setindia"': 190,
#  '"Talk Show"': 190,
#  '"sony tv"': 189,
#  '"dial 100"': 189,
#  '"weird"': 189,
#  'true events': 188,
#  '"crimes against women"': 188,
#  '"indian television"': 188,
#  '"anoop soni"': 188,
#  '"hindi crime serials"': 188,
#  '"The Young Turks"': 187,
#  '"top"': 187,
#  '"radio"': 187,
#  '"desi"': 186,
#  '"girls"': 186,
#  'ABS-CBN': 186,
#  '"season"': 186,
#  '"responds"': 186,
#  'NBA': 186,
#  '"tips"': 185,
#  '"crimes in india"': 184,
#  '"marvel"': 184,
#  '"anup soni"': 183,
#  '"murder case"': 183,
#  '"respond"': 183,
#  '"logan"': 182,
#  '"dance"': 182,
#  '"lyric breakdown"': 182,
#  '"sony entertainment channel"': 182,
#  '"crime patrol diall 100"': 182,
#  '"canada"': 181,
#  '"how to make"': 181,
#  '"do they know it"': 181,
#  '"test"': 181,
#  '"parents react"': 181,
#  '"comics"': 180,
#  '"laugh challenge"': 180,
#  '"crime patrol latest episode"': 180,
#  '"adults react"': 179,
#  '"mma"': 179,
#  '"sketch comedy"': 179,
#  '"complex"': 179,
#  'latest News': 179,
#  '"Happening Now"': 179,
#  '"CBC"': 178,
#  '"try"': 177,
#  '"vlogs"': 177,
#  '"TYT"': 177,
#  '"no swearing"': 177,
#  '"competition"': 176,
#  '"earth"': 176,
#  '"HD"': 176,
#  '"avengers"': 176,
#  '"Late Show"': 175,
#  '"creepy"': 175,
#  '"UFC"': 175,
#  '"nerf"': 175,
#  '"experiment"': 175,
#  '"good mythical morning"': 174,
#  'The Late Show': 174,
#  '"james"': 174,
#  '"exclusive"': 174,
#  '"kids versus food"': 173,
#  '"staff reacts"': 173,
#  '"Records"': 173,
#  '"mlg"': 173,
#  '"cavs"': 172,
#  '"Highlights"': 172,
#  '"punjabi romantic songs"': 171,
#  '"pop"': 171,
#  '"business"': 171,
#  '"taste test"': 171,
#  '"Food"': 171,
#  '"prank"': 170,
#  '"10"': 170,
#  '"stand up"': 170,
#  '"complex media"': 170,
#  '"ocean"': 170,
#  '"monologue"': 169,
#  '"cool"': 168,
#  'Vaani rani': 168,
#  '"rani"': 168,
#  '"Radhika in funny character"': 168,
#  '"venu aravind"': 168,
#  '"SunTV"': 168,
#  '"VaniRani"': 168,
#  '"vani"': 168,
#  '"vaani"': 168,
#  '"Radhika\'s dual role serial"': 168,
#  '"Ranimma veetu kuripu"': 168,
#  '"Radhika as lawyer in serial"': 168,
#  '"radikaa"': 168,
#  '"Radhika\'s new"': 168,
#  '"edgy"': 168,
#  '"trending"': 168,
#  '"dank memes"': 168,
#  '"dank"': 168,
#  '"react gaming"': 167,
#  '"tv serial"': 167,
#  '"youtube news"': 166,
#  '"street food"': 166,
#  '"Cenk Uygur"': 166,
#  '"mythical morning"': 165,
#  '"matpat"': 165,
#  '"stand-up"': 165,
#  '"the ellen show"': 165,
#  '"dank meme compilation"': 165,
#  '"Liberal"': 164,
#  '"dank memes compilation"': 164,
#  '"funny vines"': 164,
#  '"infinity war"': 164,
#  '"punjab"': 163,
#  '"skits"': 163,
#  '"cartoon"': 163,
#  '"philip defranco"': 163,
#  '"cosmetics"': 163,
#  '"ellen degeneres"': 163,
#  '"no cursing"': 163,
#  '"golden state warriors"': 162,
#  '"IPC section"': 161,
#  '"warriors"': 161,
#  '"meme compilation"': 161,
#  '"fortnite"': 161,
#  '"funniest"': 160,
#  '"foodie"': 160,
#  '"reacts"': 159,
#  '"drake"': 159,
#  '"fresh memes"': 159,
#  '"seth"': 158,
#  '"the philip defranco show"': 158,
#  '"gordon"': 158,
#  '"best memes"': 158,
#  '"dank compilation"': 158,
#  '"BuzzFeed"': 157,
#  '"philip defranco show"': 157,
#  '"time"': 157,
#  '"Pakistan"': 156,
#  '"subreddit"': 156,
#  '"twitter"': 156,
#  '"dj envy"': 156,
#  '"documentary"': 155,
#  '"sxephil"': 155,
#  '"charlamagne tha god"': 155,
#  '"weekend update"': 154,
#  '"dank meme"': 154,
#  '"RT"': 153,
#  '"gmm"': 153,
#  '"crime"': 153,
#  '"apple"': 153,
#  '"shots"': 152,
#  '"full episodes"': 152,
#  '"vlogger"': 152,
#  '"bottle flip"': 152,
#  '"school"': 151,
#  '"Official"': 151,
#  '"songs"': 151,
#  'Collegehumor': 151,
#  '"CH originals"': 151,
#  '"alien"': 151,
#  '"aliens"': 151,
#  '"reality"': 151,
#  '"cowbelly comment awards"': 151,
#  '"friendly"': 150,
#  '"news satire"': 150,
#  '"cnn"': 150,
#  '"DeFranco"': 150,
#  '"walkthrough"': 150,
#  '"funny meme"': 150,
#  '"channel"': 149,
#  '"vine"': 149,
#  '"pg"': 149,
#  'the breakfast club': 149,
#  '"power1051"': 149,
#  '"angela yee"': 149,
#  '"dankest"': 149,
#  '"memes compilation"': 149,
#  '"brazil"': 148,
#  '"russia"': 148,
#  '"snl seth meyers"': 148,
#  '"meyers"': 148,
#  '"lebron"': 148,
#  '"rhett and link good mythical morning"': 147,
#  '"good mythical morning rhett and link"': 147,
#  '"new punjabi songs"': 147,
#  '"action"': 147,
#  '"everything wrong with"': 147,
#  '"tonight"': 147,
#  '"lifehacks"': 147,
#  '"team edge"': 147,
#  '"crafts"': 146,
#  '"team edge challenge"': 146,
#  '"ellen audience"': 146,
#  '"funny memes"': 146,
#  '"new memes"': 146,
#  '"ethan and hila"': 145,
#  '"variety"': 145,
#  '"theatre"': 145,
#  '"fox sports"': 145,
#  '"sab tv serials"': 145,
#  '"black panther"': 145,
#  '"breaking"': 145,
#  '"useful things"': 144,
#  '"trick shots"': 144,
#  'sab tv channel': 144,
#  '"comedy channel india"': 144,
#  '"anitta"': 143,
#  '"actor"': 143,
#  'jimmy': 143,
#  '"lifestyle"': 143,
#  '"teamedge"': 143,
#  '"GOP"': 143,
#  '"fs1"': 143,
#  '"universe"': 143,
#  '"fox news"': 143,
#  '"star"': 142,
#  '"progressive"': 142,
#  '"taarak mehta ka ooltah chashmah"': 142,
#  '"jethalal"': 142,
#  '"hannahstocking"': 141,
#  '"cowbelly"': 141,
#  '"dankest memes"': 141,
#  '"tappu sena"': 141,
#  '"Taarak Mehta"': 141,
#  '"Daya"': 141,
#  '"Champaklal"': 141,
#  '"Atmaram Bhide"': 141,
#  '"Hansraj Hathi"': 141,
#  '"babita"': 141,
#  '"Gokuldham society"': 141,
#  '"jethalal comedy"': 141,
#  '"taarak mehta full"': 141,
#  '"graham the christian"': 141,
#  '"lelepons"': 140,
#  '"rudymancuso"': 140,
#  '"alesso"': 140,
#  '"pop culture"': 140,
#  '"inanna"': 139,
#  '"anwar"': 139,
#  '"mistakes"': 139,
#  '"comedy sketches"': 139,
#  '"Fallon Stand-up"': 139,
#  '"Fox News"': 139,
#  '"shotsstudios"': 138,
#  '"try to watch without laughing or grinning"': 138,
#  '"eww"': 138,
#  '"cinemasins"': 138,
#  '"cinema sins"': 138,
#  '"list"': 138,
#  '"fox sports 1"': 138,
#  '"media"': 138,
#  '"moon"': 138,
#  '"Toronto"': 138,
#  '"तारक मेहता"': 138,
#  '"sarkis"': 137,
#  '"history"': 137,
#  '"fail compilation"': 137,
#  '"impressions"': 137,
#  '"Fallon monologue"': 137,
#  '"dr phil"': 137,
#  '"new punjabi songs 2018"': 137,
#  '"ufo"': 136,
#  '"reacting"': 136,
#  '"fox"': 136,
#  '"video game"': 135,
#  '"Jimmy Fallon"': 135,
#  '"dank memes 2017"': 135,
#  '"Hop"': 135,
#  '"vox"': 134,
#  '"hot topics"': 134,
#  '"family games"': 134,
#  '"ellentube"': 134,
#  '"episode"': 134,
#  '"punjabi bhangra"': 133,
#  '"sp:st=icehockey"': 133,
#  '"sp:li=NHL"': 133,
#  '"The Late Late Show"': 133,
#  '"NHL"': 133,
#  '"hot"': 132,
#  '"girlfriend"': 132,
#  '"Philippines"': 132,
#  '"NASA"': 132,
#  '"fight"': 132,
#  '"Makeup"': 132,
#  'the real': 132,
#  '"tamera mowry"': 132,
#  '"adrienne bailon"': 132,
#  '"loni love"': 132,
#  '"jeannie mai"': 132,
#  '"Interview"': 132,
#  '"explain"': 131,
#  '"wrestling"': 131,
#  '"ellen fans"': 131,
#  '"Love"': 131,
#  '"ABS-CBN Philippines"': 131,
#  '"food porn"': 131,
#  '"kek"': 131,
#  '"Hip"': 131,
#  '"texas"': 130,
#  '"trevor noah"': 130,
#  'espn': 130,
#  '"ellen tickets"': 130,
#  '"Vice Ganda"': 130,
#  '"high profile case"': 130,
#  '"money"': 129,
#  '"smosh"': 129,
#  '"iphone x"': 129,
#  '"smith"': 129,
#  '"hockey"': 129,
#  '"Russia"': 128,
#  '"strange"': 128,
#  '"jethalal gada"': 128,
#  '"punjabi songs 2018"': 128,
#  '"boyfriend"': 127,
#  '"Hollywood"': 127,
#  '"Breaking News"': 127,
#  '"comedy videos"': 127,
#  '"edgy memes"': 127,
#  '"logang"': 126,
#  '"improv"': 126,
#  '"ARY"': 126,
#  '"new dank memes"': 126,
#  '"crimes agaiinst women"': 126,
#  '"skit"': 125,
#  '"espn live"': 125,
#  '"Kitchen Nightmares"': 125,
#  '"Hotel Hell"': 125,
#  '"toronto"': 125,
#  'The Tonight Show': 124,
#  '"white house"': 124,
#  '"austin"': 123,
#  '"day"': 123,
#  '"gmm food"': 123,
#  'Joe Rogan Experience': 123,
#  '"kids games"': 123,
#  '"water"': 123,
#  '"Marvel"': 123,
#  '"cocktail"': 123,
#  '"freestyle"': 123,
#  '"comedy channel hindi"': 123,
#  '"speed records"': 122,
#  '"team"': 122,
#  '"fails compilation"': 122,
#  '"the daily show"': 122,
#  '"planet"': 122,
#  '"chicken"': 122,
#  '"White House"': 122,
#  '"fwf"': 122,
#  '"firstwefeast"': 122,
#  '"news today"': 122,
#  '"punjabi bhangra music"': 121,
#  '"production"': 121,
#  '"epic fails"': 121,
#  '"funny fails"': 121,
#  '"Republican"': 121,
#  'hkayet tounsia': 121,
#  '"elhiwar ettounsi"': 121,
#  '"denya okhra"': 121,
#  '"oumour jedia"': 121,
#  '"karim el gharbi"': 121,
#  '"divertissement"': 121,
#  '"lakers"': 121,
#  '"people"': 121,
#  '"Live"': 121,
#  '"audition"': 121,
#  '"keemstar"': 120,
#  '"wow"': 120,
#  '"Film"': 120,
#  '"simon cowell"': 120,
#  '"doug demuro"': 120,
#  '"Animation"': 120,
#  'comedy central': 120,
#  '"comedy central uk"': 120,
#  '"TYT Network"': 120,
#  'mystery': 120,
#  '"ARY Digital"': 120,
#  '"sab tv live"': 120,
#  '"sab tv new show 2016"': 120,
#  'best vines 2018': 120,
#  '"funniest videos 2018"': 120,
#  '"bhangra"': 119,
#  '"cheap"': 119,
#  '"life"': 119,
#  '"andi mankolek"': 119,
#  '"oumour jeddya"': 119,
#  '"dari deco"': 119,
#  '"360 degrees"': 119,
#  '"klem ennes"': 119,
#  '"ma binetna"': 119,
#  '"liman yajroo fakat"': 119,
#  '"labes"': 119,
#  '"labas"': 119,
#  '"awled mofida"': 119,
#  '"maktoub"': 119,
#  '"el hak maak"': 119,
#  '"wled moufida"': 119,
#  '"awled moufida"': 119,
#  '"اليوم الثامن"': 119,
#  '"عندي ما نقلك"': 119,
#  '"مكتوب"': 119,
#  '"أمور جدّية"': 119,
#  '"أولاد مفيده"': 119,
#  '"supernatural"': 119,
#  '"Green"': 118,
#  '"tech"': 118,
#  '"conservative"': 118,
#  '"wrestler"': 118,
#  '"happy nes"': 118,
#  '"antarctica"': 118,
#  '"craft beer"': 118,
#  '"robert mueller"': 118,
#  '"gadgets"': 117,
#  '"youtuber"': 117,
#  '"Joe Rogan"': 117,
#  '"hiphop"': 117,
#  '"Best"': 117,
#  '"priyamanaval serial"': 117,
#  '"piriyamanaval"': 117,
#  '"பிரியமானவள்"': 117,
#  '"priyamanaval episode"': 117,
#  '"periyamanaval"': 117,
#  '電視劇': 116,
#  '"大陸電視劇"': 116,
#  '"rathika"': 116,
#  '"Hip Hop"': 116,
#  '"Cook (Profession)sean evans"': 116,
#  '"punjabi sad songs"': 115,
#  '"web series"': 115,
#  '"fail compilation 2017"': 115,
#  'SciShow': 115,
#  '"Hank"': 115,
#  '"kevin durant"': 115,
#  '"secureteam10"': 115,
#  'First we feast': 115,
#  '"top10"': 114,
#  '"NBA"': 114,
#  '"fails of the week"': 114,
#  '"ABS-CBN Online"': 114,
#  '"mars"': 114,
#  '"political humour"': 114,
#  '"Do it yourself"': 114,
#  '"DIY projects"': 114,
#  '"Handcraft"': 114,
#  '"how"': 114,
#  '"cleveland"': 114,
#  '"phil"': 114,
#  '"sean evans"': 114,
#  '"bartender"': 114,
#  '"president"': 114,
#  '"worldstar"': 114,
#  '"olympics"': 113,
#  '"worst"': 113,
#  '"good mythical more"': 113,
#  '"relationships"': 113,
#  '"daily show"': 113,
#  '"jimmy kimmel"': 113,
#  'comment': 113,
#  '"rhett and link good mythical more"': 112,
#  '"good mythical more rhett and link"': 112,
#  '"skateboarding"': 112,
#  '"secret"': 112,
#  '"DIY activities"': 112,
#  '"home"': 112,
#  '"new york"': 112,
#  '"ufos"': 112,
#  '"epic"': 112,
#  '"huge"': 111,
#  '"MSNBC news"': 111,
#  '"japan"': 111,
#  '"world wrestling entertainment"': 111,
#  '"पहलवान"': 111,
#  '"सुपरस्टार"': 111,
#  '"व्यावसायिक कुश्ती"': 111,
#  '"مصارعه"': 111,
#  '"amazon"': 111,
#  '"nhar lahad ma hemek fi had"': 111,
#  '"sami fehri"': 111,
#  '"نهار الأحد ما يهمّك في حدّ"': 111,
#  '"نهار الأحد"': 111,
#  '"the voice"': 111,
#  '"us"': 111,
#  '"team 10"': 110,
#  '"superhero"': 110,
#  '"filmmaking"': 110,
#  '"fails 2017"': 110,
#  '"phone"': 110,
#  '"Sports"': 110,
#  '"unbox"': 110,
#  '"superstars"': 110,
#  '"first take"': 110,
#  '"degeneres"': 110,
#  '"teenagers react"': 110,
#  '"latest news"': 110,
#  '"night"': 109,
#  'news': 109,
#  '"Celebrity"': 109,
#  '"fail army"': 109,
#  '"Football"': 109,
#  '"android"': 109,
#  '"official trailer"': 109,
#  '"Romantic"': 109,
#  '"reacting to"': 109,
#  '"unsolved"': 109,
#  '"learning"': 109,
#  '"easy"': 109,
#  '"comment awards"': 109,
#  '"thriller series"': 109,
#  '"MSNBC TV"': 108,
#  '"fail laugh"': 108,
#  '"fails of the month"': 108,
#  '"stephen curry"': 108,
#  '"do it yourself"': 108,
#  '"wrestle"': 108,
#  '"कुश्ती"': 108,
#  '"डब्लू डब्लू ई"': 108,
#  '"मैच"': 108,
#  '"dr."': 108,
#  '"friends"': 108,
#  '"political news"': 107,
#  '"restaurant"': 107,
#  'wwe': 107,
#  '"Progressive"': 107,
#  '"Democratic"': 107,
#  '"kanye west"': 107,
#  '"fake news"': 107,
#  '"soccer"': 107,
#  '"baby"': 107,
#  '"worldstarhiphop"': 107,
#  '"bhide scooter"': 107,
#  'punjabi songs': 106,
#  '"MSNBC live"': 106,
#  'failarmy': 106,
#  '"bad friends"': 106,
#  '"scooter fail"': 106,
#  '"failarmy kids"': 106,
#  '"failarmy parkour"': 106,
#  '"failarmy animals"': 106,
#  '"failarmy cats"': 106,
#  '"failarmy instant karma"': 106,
#  '"clean"': 106,
#  '"singing"': 106,
#  '"ovni"': 106,
#  '"performance"': 106,
#  '"Full Game Highlights"': 106,
#  '"Rapid Highlights"': 106,
#  '"seth meyers"': 106,
#  '"top stories"': 106,
#  '"hindi crime drama"': 106,
#  '"elections"': 105,
#  '"workout fails"': 105,
#  '"sharpe"': 105,
#  '"Showbiz"': 105,
#  '"Movie"': 105,
#  '"president donald trump"': 105,
#  '"Robert Mueller"': 105,
#  '"new the daily show"': 105,
#  '"BuzzFeedVideo"': 105,
#  'Rooster Teeth': 104,
#  '"Paul"': 104,
#  '"therapy"': 104,
#  '"US news"': 104,
#  '"fail army funny"': 104,
#  '"相亲"': 104,
#  '"pets"': 104,
#  '"New"': 104,
#  '"children"': 104,
#  '"homemade"': 104,
#  '"undisputed"': 104,
#  '"theory"': 104,
#  '"ghost"': 104,
#  '"trường giang"': 104,
#  '"nhl"': 104,
#  '"rap music"': 104,
#  '"make"': 103,
#  '"wedding"': 103,
#  'reaction time': 103,
#  '"free time"': 103,
#  '"tal fishman"': 103,
#  '"game time"': 103,
#  '"MMA"': 103,
#  '"latest songs"': 103,
#  '"random happens"': 103,
#  '"skip bayless"': 103,
#  '"shannon sharpe"': 103,
#  '"skip and shannon"': 103,
#  '"fs1 undisputed"': 103,
#  '"joy taylor"': 103,
#  '"curry"': 103,
#  '"luxury"': 103,
#  '"politics news"': 102,
#  '"late night show"': 102,
#  '"demuro"': 102,
#  '"trucos de belliza"': 102,
#  '"grant thompson"': 102,
#  '"life hacks"': 102,
#  '"stephen a smith"': 102,
#  '"random"': 102,
#  'fox': 102,
#  '"wshh"': 102,
#  '"Nino"': 102,
#  '"avengers infinity war"': 102,
#  '#DramaAlert': 101,
#  '"Alert"': 101,
#  '"DramaAlert"': 101,
#  '"unexplained"': 101,
#  '"eating"': 101,
#  '"the wendy williams show"': 101,
#  '"série"': 101,
#  '"shannon"': 101,
#  '"egoraptor"': 101,
#  '"danny"': 101,
#  '"gamegrumps"': 101,
#  '"film theory"': 101,
#  '"daily show episodes"': 101,
#  '"Season 13"': 101,
#  '"刘烨"': 100,
#  '"questions"': 100,
#  '"unbox therapy"': 100,
#  '"Obama"': 100,
#  '"#youtubeblack"': 100,
#  '"bayless"': 100,
#  'lets': 100,
#  '"ksi"': 100,
#  '"kid"': 100,
#  '"star wars"': 100,
#  '"The"': 100,
#  '"wild"': 100,
#  '"Dance"': 100,
#  '"fresh"': 100,
#  '"US News"': 100,
#  '"every"': 99,
#  '"黄磊"': 99,
#  '"samsung"': 99,
#  '"king of random"': 99,
#  '"recipes"': 99,
#  '"drugstore"': 99,
#  '"skip"': 99,
#  '"grumps"': 99,
#  '"monster"': 99,
#  '"food challenge"': 99,
#  '"teaser"': 99,
#  '"Hockey"': 99,
#  '"Video"': 99,
#  '"Disney"': 99,
#  '"funny moments"': 99,
#  '"memes 2017"': 99,
#  '"lonzo ball"': 99,
#  '"taarak mehta new episode"': 99,
#  '"Review"': 98,
#  '"smartphone"': 98,
#  '"behind the scenes"': 98,
#  '"stephen a. smith"': 98,
#  '"tran thanh"': 98,
#  '"the king of random"': 98,
#  '"style"': 98,
#  '"Recipe"': 98,
#  '"Christmas"': 98,
#  '"peterson"': 98,
#  '"محمد صلاح"': 98,
#  '"Pranks"': 98,
#  '"raffy tulfo"': 98,
#  '"iron man"': 98,
#  '"comedy show"': 98,
#  '"online"': 97,
#  '"david letterman"': 97,
#  '"real"': 97,
#  '"bts"': 97,
#  '"explained"': 97,
#  '"it’s raw"': 97,
#  '"taarak mehta comedy"': 97,
#  '"best comedy show"': 97,
#  '"pranks"': 96,
#  '"ufc"': 96,
#  '"help"': 96,
#  '"NBC News"': 96,
#  '"nozman"': 96,
#  '"wled mofida"': 96,
#  '"لا بــــاس"': 96,
#  '"educational"': 96,
#  '"Florida"': 96,
#  '"wanted sa radyo"': 96,
#  '"hip hop music"': 96,
#  '"gordon ramsay"': 96,
#  '"都市"': 95,
#  '"brothers"': 95,
#  '"bit"': 95,
#  '"letterman"': 95,
#  '"iphone 8"': 95,
#  '"proyectos faciles"': 95,
#  '"tv5"': 95,
#  '"college kids react"': 95,
#  '"funny dank memes"': 95,
#  '"daily show 2017"': 95,
#  '"trap"': 94,
#  '"Justin Trudeau"': 94,
#  '"grant thompson king of random"': 94,
#  '"boston celtics"': 94,
#  '"coyote"': 94,
#  '"gossip"': 94,
#  '"bollywood"': 94,
#  '"kimmel"': 94,
#  '"magic"': 94,
#  '"crime thriller"': 94,
#  '"apple iphone x"': 93,
#  '"john"': 93,
#  '"trump news"': 93,
#  '"trucos"': 93,
#  '"JRE"': 93,
#  'dr nozman': 93,
#  '"stephen"': 93,
#  '"hi5 studios"': 93,
#  '"Cooking"': 93,
#  '"mysteries"': 93,
#  '"cardi b"': 93,
#  '"RCA Records Label"': 93,
#  '"cable"': 93,
#  '"unsolved crimes"': 93,
#  '"مسلسلات رمضان 2018"': 93,
#  'Graham Norton': 92,
#  '"YouTube"': 92,
#  '"BuzzFeed Tasty"': 92,
#  '"truth"': 92,
#  '"ending"': 92,
#  '"Variety"': 92,
#  '"hot ones"': 92,
#  '"joe"': 92,
#  '"asmr"': 92,
#  '"Family"': 92,
#  '"tulfo in action"': 92,
#  '"super bowl"': 92,
#  '"Priyamanaval episode today"': 92,
#  '"dog"': 91,
#  '"buzzfeed"': 91,
#  '"couple"': 91,
#  '"uberhaxornova"': 91,
#  '"Action"': 91,
#  '"msnbc"': 91,
#  '"first take today"': 91,
#  'mlg highlights': 91,
#  '"race"': 91,
#  '"sun"': 91,
#  '"bon appétit"': 91,
#  '"coyote peterson"': 91,
#  'tulfo': 91,
#  '"raffy tulfo in action"': 91,
#  '"Trending"': 91,
#  '"Hi5 Studios"': 91,
#  '"comment"': 91,
#  '"Priyamanaval today"': 91,
#  '"مسلسلات رمضان"': 91,
#  '"official video"': 90,
#  '"Graham Norton Show Official"': 90,
#  '"haul"': 90,
#  '"nikkietutorials"': 90,
#  '"tvpromosdb"': 90,
#  '"series"': 90,
#  '"tkor"': 90,
#  '"breaking trail"': 90,
#  '"true crime"': 90,
#  '"pop music"': 90,
#  '"news channel"': 90,
#  '"Priyamanaval today Episode"': 90,
#  '"top crime series"': 90,
#  '"Leafs"': 89,
#  '"haunted"': 89,
#  '"Slow Motion"': 89,
#  '"honest trailers"': 89,
#  '"thekingofrandom"': 89,
#  'senegal': 89,
#  '"youssou ndour;musique"': 89,
#  '"téléfilm"': 89,
#  ...}

# %%
## Plot word frequencey graph for top 50 most occuring word
wordsList = []
countList = []
for key,val in sortedDict.items():
    wordsList.append(key)
    countList.append(val)
fig, axs=plt.subplots(figsize=(20,10))
axs.plot(wordsList[:50],countList[:50])
axs.set_xticklabels(wordsList[:50],fontsize=10)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_28756/337430360.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(wordsList[:50],fontsize=10)

# %%
## Word Cloud of most frequently used Tags
cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(tagsDictionary)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ### How number of word in Title affect Trending videos!!!

# %%
## Length of title..
titleList = []
for i,row in videoCompleteDF.iterrows():
    titleList.append(len(row["title"].split(" ")))
videoCompleteDF["titleWordCount"] = titleList
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# 40876                       HOW2: How to Solve a Mystery   Annoying Orange
# 40877                   Eli Lik Lik Episode 13 Partie 01  Elhiwar Ettounsi
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    Kingdom Hearts
# 40879                   Trump Advisor Grovels To Trudeau   The Young Turks
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班          我愛小明星大跟班
#
#        category_id              publish_time  \
# 0               10  2017-11-10T17:00:03.000Z
# 1               23  2017-11-13T17:00:00.000Z
# 2               23  2017-11-12T19:05:24.000Z
# 3               24  2017-11-12T18:01:41.000Z
# 4               10  2017-11-09T11:04:14.000Z
# ...            ...                       ...
# 40876           24  2018-06-13T18:00:07.000Z
# 40877           24  2018-06-13T19:01:18.000Z
# 40878           20  2018-06-11T17:30:53.000Z
# 40879           25  2018-06-13T04:00:05.000Z
# 40880           24  2018-06-13T16:00:03.000Z
#
#                                                     tags     views    likes  \
# 0      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1      plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4      edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
# ...                                                  ...       ...      ...
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...     80685     1701
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...    103339      460
# 40878  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...    773347    25900
# 40879  180612__TB02SorryExcuse|"News"|"Politics"|"The...    115225     2115
# 40880  吳宗憲|"吳姍儒"|"小明星大跟班"|"Sandy"|"Jacky wu"|"憲哥"|"中天...    107392      300
#
#        dislikes  comment_count  \
# 0         43420         125882
# 1          1688          13030
# 2          5339           8181
# 3          1989          17518
# 4         21082          85067
# ...         ...            ...
# 40876        99           1312
# 40877        66             51
# 40878       224           3881
# 40879       182           1672
# 40880        62            251
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 1      https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# 4      https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg              False
# ...                                               ...                ...
# 40876  https://i.ytimg.com/vi/sGolxsMSGfQ/default.jpg              False
# 40877  https://i.ytimg.com/vi/8HNuRNi8t70/default.jpg              False
# 40878  https://i.ytimg.com/vi/GWlKEM3m2EE/default.jpg              False
# 40879  https://i.ytimg.com/vi/lbMKLzQ4cNQ/default.jpg              False
# 40880  https://i.ytimg.com/vi/POTgw38-m58/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40876             False                   False
# 40877             False                   False
# 40878             False                   False
# 40879             False                   False
# 40880             False                   False
#
#                                              description    category_name  \
# 0      Eminem's new track Walk on Water ft. Beyoncé i...            Music
# 1      STill got a lot of packages. Probably will las...           Comedy
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...           Comedy
# 3      I know it's been a while since we did this sho...    Entertainment
# 4      🎧: https://ad.gt/yt-perfect\n💰: https://atlant...            Music
# ...                                                  ...              ...
# 40876  🚨 NEW MERCH! http://amzn.to/annoyingorange 🚨➤ ...    Entertainment
# 40877  ► Retrouvez vos programmes préférés : https://...    Entertainment
# 40878  Find out more about Kingdom Hearts 3: https://...           Gaming
# 40879  Peter Navarro isn’t talking so tough now. Ana ...  News & Politics
# 40880  藝人：李妍瑾、玉兔、班傑、LaLa、小優、少少專家：陳筱屏(律師)、Wendy(心理師)、羅...    Entertainment
#
#        titleWordCount
# 0                   8
# 1                   6
# 2                  10
# 3                   5
# 4                   7
# ...               ...
# 40876               6
# 40877               7
# 40878              10
# 40879               5
# 40880               1
#
# [40881 rows x 18 columns]

# %%
TODO::::
# Out:
#   Input In [22]
#     TODO::::
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <a id= "obj2"></a>
# ## Objective 2 : Check how engagement metrics are crucial for trending videos!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
videos=pd.read_csv("CAvideos.csv")
# print(videos.head(5))
newvideos=videos[["views","likes","dislikes","comment_count","trending_date","publish_time"]]
newvideos['trending_date'] = pd.to_datetime(newvideos['trending_date'], format='%y.%d.%m')
newvideos['publish_time'] = pd.to_datetime(newvideos['publish_time'])
# for i,k in newvideos.iterrows():
    
#     newvideos.loc[i,"publish_time"]= datetime.strptime(k["publish_time"], "%Y-%m-%dT%H:%M:%S.%fZ")
    
# newvideos[["trending_date","publish_time"]]=newvideos[["trending_date","publish_time"]].astype(float)
print(newvideos.head(-30))
# Out:
# C:\Users\aishp\AppData\Local\Temp\ipykernel_6572\396586287.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newvideos['trending_date'] = pd.to_datetime(newvideos['trending_date'], format='%y.%d.%m')
#           views    likes  dislikes  comment_count trending_date  \
# 0      17158579   787425     43420         125882    2017-11-14
# 1       1014651   127794      1688          13030    2017-11-14
# 2       3191434   146035      5339           8181    2017-11-14
# 3       2095828   132239      1989          17518    2017-11-14
# 4      33523622  1634130     21082          85067    2017-11-14
# ...         ...      ...       ...            ...           ...
# 40846   1002708    16131       445           4935    2018-06-14
# 40847    537722     3888       458             37    2018-06-14
# 40848    214076     8835       123           1787    2018-06-14
# 40849    170581     3498       140           1401    2018-06-14
# 40850    981033    71996       363           8756    2018-06-14
#
#                    publish_time
# 0     2017-11-10 17:00:03+00:00
# 1     2017-11-13 17:00:00+00:00
# 2     2017-11-12 19:05:24+00:00
# 3     2017-11-12 18:01:41+00:00
# 4     2017-11-09 11:04:14+00:00
# ...                         ...
# 40846 2018-05-14 22:34:33+00:00
# 40847 2018-06-12 10:39:54+00:00
# 40848 2018-06-13 12:00:35+00:00
# 40849 2018-06-12 11:21:19+00:00
# 40850 2018-06-10 15:00:02+00:00
#
# [40851 rows x 6 columns]
# C:\Users\aishp\AppData\Local\Temp\ipykernel_6572\396586287.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newvideos['publish_time'] = pd.to_datetime(newvideos['publish_time'])

# %%
# calculate the correlation coefficient
correlation_matrix = newvideos.corr()
correlation_matrix
# Out:
#                   views     likes  dislikes  comment_count  trending_date  \
# views          1.000000  0.828964  0.557621       0.693107       0.006967
# likes          0.828964  1.000000  0.460427       0.836585      -0.000663
# dislikes       0.557621  0.460427  1.000000       0.643494      -0.016650
# comment_count  0.693107  0.836585  0.643494       1.000000      -0.002586
# trending_date  0.006967 -0.000663 -0.016650      -0.002586       1.000000
# publish_time   0.004358  0.001463 -0.011588       0.000106       0.730745
#
#                publish_time
# views              0.004358
# likes              0.001463
# dislikes          -0.011588
# comment_count      0.000106
# trending_date      0.730745
# publish_time       1.000000

# %%
#correlation graph

# scatter plots to visualize the correlation between pairs of metrics

# g = pd.plotting.scatter_matrix(newvideos, figsize=(10,10), marker = 'o', hist_kwds = {'bins': 10}, s = 60, alpha = 0.8)
sns.pairplot(newvideos, diag_kws={'bins': 30})

# %%
#correlation matrix using heatmap

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aishp\OneDrive\Documents\GitHub\Trending_youtube_Video\Factor Affecting youtube Videos.ipynb Cell 46 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aishp/OneDrive/Documents/GitHub/Trending_youtube_Video/Factor%20Affecting%20youtube%20Videos.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> df.shape
#
# NameError: name 'df' is not defined

# %%
tahtemp =[]
for i, row in df.iterrows():
    tahtemp.append(row["tags"].split("|"))
tahtemp[12]

# %%
## common methods
# what methods does.!!!

# %%
df.groupby(by="publish_time").count().sort_values(by="video_id",ascending=False)

# %%
def getColumnsList(data):
    return [ x for x in data.columns]

# %%
df.info(null_counts=True)

# %%
jsonDF = pd.read_json("../archive/CA_category_id.json")
jsonDF.head()

# %%
jsonDF.shape

# %%
jsonDF["items"][0]

# %%
def getCategoryFromJson(data):
    import json
    category = {}
    for i, row in data.iterrows():
        tempdict = dict(row)
        category[tempdict["items"]["id"]]= tempdict["items"]["snippet"]["title"]
    return category
getCategoryFromJson(jsonDF)

# %%
def appendCategoryToDataFrame(dataFrame,category):
    tempList = []
    for i,row in dataFrame.iterrows():
        if str(row["category_id"]) in category.keys():
            tempList.append(category[str(row["category_id"])])
        else :
            tempList.append(None)
    df["category_name"] = tempList
appendCategoryToDataFrame(df,getCategoryFromJson(jsonDF))
getColumnsList(df)

# %%
df[df["category_name"] == "p"].count()

# %%
category.keys()

# %%
(type(row["category_id"]))

# %%
df.columns

# %% [markdown]
# Objective : Time to trends, and its relation between category

# %%
#import date
from datetime import datetime,timezone
tempDateList = []
for i, row in df.iterrows():
    tempDateList.append(datetime.fromisoformat(row["publish_time"][:-1]).astimezone(timezone.utc).strftime('%Y-%m-%d %H:%M:%S'))
    
df["publishDate"] = tempDateList

# %%
df["publishDate"]

# %%
df["publishDate"] = pd.to_datetime(df["publishDate"])

# %% [markdown]
# time to trend

# %%
#import date
from datetime import datetime,timezone
trendingDate = []
for i, row in df.iterrows():
#     date = datetime.datetime.strptime(day.group(), '%Y-%m-%d').date()
    trendingDate.append((datetime.strptime(row["trending_date"], '%y.%d.%m').strftime('%Y-%m-%d')))

df["trending_date"] = trendingDate
df["trending_date"] = pd.to_datetime(df["trending_date"])

# %%
df["treandingDiff"]=df["trending_date"] - df["publishDate"]

# %%
df.columns

# %%
df.head(10)

# %%
requiredDF = df[["category_id","category_name","treandingDiff"]]
requiredDF

# %%
requiredDF.columns

# %%
requiredDF["treandingDiff"].describe()

# %%
df_gB = df.groupby(by="category_name").count()
df_gB

# %%
df.groupby(by="channel_title").count().sort_values("video_id", ascending=False)

# %%
requiredDF["category_name"]

# %%
# import matplotlib.pyplot as plt
# plt.bar(requiredDF[requiredDF["category_id"] == 1]["category_id"],requiredDF[requiredDF["category_id"] == 1]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 2]["category_id"],requiredDF[requiredDF["category_id"] == 2]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 23]["category_id"],requiredDF[requiredDF["category_id"] == 23]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 24]["category_id"],requiredDF[requiredDF["category_id"] == 24]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 10]["category_id"],requiredDF[requiredDF["category_id"] == 10]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 25]["category_id"],requiredDF[requiredDF["category_id"] == 25]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 22]["category_id"],requiredDF[requiredDF["category_id"] == 22]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 26]["category_id"],requiredDF[requiredDF["category_id"] == 26]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 28]["category_id"],requiredDF[requiredDF["category_id"] == 28]["treandingDiff"])

# %%
XVal=requiredDF["category_name"].unique()
XVal

# %%
YVal = requiredDF["category_name"].value_counts()
YVal

# %%
plt.bar(XVal,YVal)

# %%
### like to dislike ratio
### view ratio
### View per category

# %%
df["channel_title"].value_counts()[:25]

# %%
df.sort_values("views", ascending=False)

# %%
Factor

# %%
import sklearn.neighbors as skn
from sklearn.model_selection import train_test_split
x = 
X_train, X_test, Y_train, Y_train = train_test_split()

# %%
# # correc the type of tranding_date
# df["trending_date"]=pd.to_datetime(df["trending_date"],format="%y.%d.%m")
# # correct the type of published_time
# df["publish_time"]=pd.to_datetime(df["publish_time"])

# %%
##Object 1 :

# %%
##Object 2 :

# %%
##Object 3 :

# %%
##Object 4 :

# %% [markdown]
# <div id="Introduction">
# <h1 style="background:black;padding:5%">
#     <span style="color:red"> Factor Affecting</span><span style="color:white"> Trending Video</span><span style="color:red"> On Youtube. </span>
#     <img style="width:50px;height:50px; top-padding:3%; background:white" src="./youtube.svg">
# </h1>
# </div>

# %% [markdown]
# ## Youtube is a online video sharing and social media platform, headquatered in California, United States. Accessable Worldwide, It was launched on February 14, 2005 by Jawed Karim, Steve Chen and Chad Hurley. Its parent company is Google and is the second most visited website just after google search. It has over 2.5 billion monthlty active user, who watch around 1 billion hours of video every day..
#
# <h2 style="color:red">continue this and plz relate this to video and our analisys.. </h2>
#
# ***

# %% [markdown]
# <a id="ProjectAim"></a>
# ## Problem Statement!!!!

# %% [markdown]
# The aim of this research project is to investigate and analyse the key factor influencing the trending videos on one of the most popular and most visited video sharing platform, Youtube.
# With such a dynamic and competitive landscape of online content and content creation, understanding the variables that contribute to a video's popularity is essential for content creators, marketers, and platform algorithms.By diving into the diverse dimensions of video content, engagement metrics, this study seeks to unveil patterns and correlations that underlie the success of YouTube videos in trending categories. Through a comprehensive examination, the project aims to provide insights that can empower content creators to optimize their strategies and enhance the overall comprehension of video trends within the YouTube platform.
#
# The study is split up into four main objective
# * How does factor like description, tags and title effect trending of videos!!!!
# * Ob2
# * Ob3
# * Ob4

# %% [markdown]
# <a id="Table"></a>
# # Table of Content
# * [Introduction](#Introduction)
# * [Problem Statement](#ProjectAim)
#     * [How does factor like description, tags and title effect trending of videos!!!!](#obj1)
#     * [Objective 2](#obj2)
#     * [Objective 3](#obj3)
#     * [Objective 4](#obj4)
# * [Table of Content](#Table)
# * [Importing modules](#importm)
# * [Importing DataSet](#importD)
#     * [Importing video dataset (C.S.V)](#csvData)
#     * [Importing category dataset (JSON)](#jsonData)
# * [Common methods](#common)
# * [Exploratory Data Analysis (E.D.A)](#eda)
#     * [Video dataset EDA](#edavideo)
#     * [Category dataset EDA](#edacat)
# * [Objective 1 : How does factor like tags, title, description effect trending of videos!!!!](#obj1)
#     * [Most Common Tags used across Trending Videos!!! ](#obj1a)
#     * [How number of word in Title affect Trending videos!!! ](#obj1b)
#     * [Curious on what to put as description?? ](#obj1c)
# * [Objective 2](#obj2)
#     * [.. make sub objective if required](#obj2a)
# * [Objective 3](#obj3)
#     * [.. make sub objective if required](#obj3a)
# * [Objective 4](#obj4)
#     * [.. make sub objective if required](#obj4a)
# * [Conclusion](#conclusion)

# %% [markdown]
# <a id="importm"> </a>
# ## Importing required modules

# %%
# !pip install session-info
# !pip install wordcloud
# !pip install textstat
# !conda install -c conda-forge wordcloud
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
from wordcloud import WordCloud
import warnings
import re
import textstat
warnings.simplefilter(action='ignore')
# Out:
# Requirement already satisfied: session-info in /home/shubham/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: stdlib-list in /home/shubham/anaconda3/lib/python3.9/site-packages (from session-info) (0.10.0)
# Requirement already satisfied: wordcloud in /home/shubham/anaconda3/lib/python3.9/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /home/shubham/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in /home/shubham/anaconda3/lib/python3.9/site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in /home/shubham/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shubham/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/shubham/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: textstat in /home/shubham/anaconda3/lib/python3.9/site-packages (0.7.3)
# Requirement already satisfied: pyphen in /home/shubham/anaconda3/lib/python3.9/site-packages (from textstat) (0.14.0)
# Collecting package metadata (current_repodata.json): \ WARNING conda.models.version:get_matcher(535): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: - ^C
# failed with initial frozen solve. Retrying with flexible solve.
#
# CondaError: KeyboardInterrupt

# %% [markdown]
# <a id="importD"></a>
# ## Importing Data

# %% [markdown]
# * The sourge of the data was Kaggle, one of the most popular data science competition platform and online community of data scientists and machine learning practitioners under Google LLC.
# * The data we are targeting is "Trending YouTube Video Statistics" This dataset is a daily record of the top trending YouTube videos.
# * MetaData of DataSet
#     * The data is segrated into two source a comma seperated values (c.s.v) and a json.
#     * The csv contain video records while json contain details of category of these videos.
#     * The data contain 40K+ record of trending videos in Canada over the span of two years!!
#     * With 40K+ rows the data also contain 16 columns including but not limited to title, publish time, views, like, dislike.
#     * The json file contain 31 categories with nested json with each category details.

# %% [markdown]
# <a id="csvData"></a>
# ### Importing video dataset (C.S.V)

# %%
videoDF = pd.read_csv("../archive/CAvideos.csv")
videoDF.head(5)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  I know it's been a while since we did this sho...
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...

# %% [markdown]
# <a id="jsonData"></a>
# ### Importing category dataset (JSON)

# %%
categoryDf = pd.read_json("../archive/CA_category_id.json")
categoryDf.head(5)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %% [markdown]
# <a id="common"></a>
# ## Common Methods

# %%
#### ADD Commmon methods here!!!!!

# %%
# method to print Json Object in readable format.. 
def printJsonObject(obj):
    line_list = obj.split("\n")
    for line in line_list:
        print(line)

# %%
# method to get category
def getCategoryFromJson(data):
    category = {}
    for i, row in data.iterrows():
        tempdict = dict(row)
        category[tempdict["items"]["id"]]= tempdict["items"]["snippet"]["title"]
    return category

# %%
# method to get combine dataFrames 
def appendCategoryToDataFrame(dataFrame,category):
    tempList = []
    for i,row in dataFrame.iterrows():
        if str(row["category_id"]) in category.keys():
            tempList.append(category[str(row["category_id"])])
        else :
            tempList.append(None)
    dataFrame["category_name"] = tempList
    return dataFrame

# %% [markdown]
# <a id="eda"></a>
# ## Exploratory Data Analysis (E.D.A)

# %% [markdown]
# <a id="edavideo"></a>
# ### Video Dataset EDA

# %%
videoDF.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
videoDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
#  14  video_error_or_removed  40881 non-null  bool
#  15  description             39585 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
videoDF.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %% [markdown]
# <a id="edacat"></a>
# ### Category Dataset EDA

# %%
categoryDf.columns
# Out:
# Index(['kind', 'etag', 'items'], dtype='object')

# %%
categoryDf.describe()
# Out:
#                                      kind  \
# count                                  31
# unique                                  1
# top     youtube#videoCategoryListResponse
# freq                                   31
#
#                                                      etag  \
# count                                                  31
# unique                                                  1
# top     "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# freq                                                   31
#
#                                                     items
# count                                                  31
# unique                                                 31
# top     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# freq                                                    1

# %%
categoryDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kind    31 non-null     object
#  1   etag    31 non-null     object
#  2   items   31 non-null     object
# dtypes: object(3)
# memory usage: 872.0+ bytes

# %%
## Exploring an complete json item in category dataset
output = json.dumps(categoryDf.iloc[0]["items"],indent=1)
printJsonObject(output)
# Out:
# {
#  "kind": "youtube#videoCategory",
#  "etag": "\"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ\"",
#  "id": "1",
#  "snippet": {
#   "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
#   "title": "Film & Animation",
#   "assignable": true
#  }
# }

# %% [markdown]
# <a id="obj1"></a>
# ## Objective 1 : How does factor like tags, title and description effect trending of videos!!!!

# %%
## Making copy of original dataframe
videoDFCP = videoDF.copy()

# %%
# getting complete Df after adding category to df
getCategoryJson = getCategoryFromJson(categoryDf)
videoCompleteDF = appendCategoryToDataFrame(videoDFCP,getCategoryJson)
videoCompleteDF.head(5)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description  category_name
# 0  Eminem's new track Walk on Water ft. Beyoncé i...          Music
# 1  STill got a lot of packages. Probably will las...         Comedy
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...         Comedy
# 3  I know it's been a while since we did this sho...  Entertainment
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...          Music

# %% [markdown]
# <a id="obj1a"></a>
# ### Most Common Tags used across Trending Videos!!

# %%
## Word Frequency of tags and sorted in decending order
tagsDictionary = {}
for i,row in videoCompleteDF.iterrows():
    for tag in row["tags"].split('|'):
        if tag in tagsDictionary:
            tagsDictionary[tag] += 1
        else:
            tagsDictionary[tag] = 1
sortedDict = dict(sorted(tagsDictionary.items(), key=lambda x:x[1], reverse=True))
sortedDict.pop("[none]")
sortedDict
# Out:
# {'"funny"': 3296,
#  '"comedy"': 2301,
#  '"news"': 1317,
#  '"2018"': 1066,
#  '"video"': 1014,
#  '"politics"': 985,
#  '"humor"': 956,
#  '"review"': 903,
#  '"food"': 894,
#  '"reaction"': 829,
#  '"music"': 821,
#  '"talk show"': 756,
#  '"interview"': 741,
#  '"family friendly"': 724,
#  '"comedian"': 724,
#  '"2017"': 715,
#  '"funny videos"': 645,
#  '"News"': 630,
#  '"react"': 622,
#  '"television"': 619,
#  '"donald trump"': 609,
#  '"trump"': 599,
#  '"how to"': 585,
#  '"basketball"': 579,
#  '"Donald Trump"': 578,
#  '"sports"': 569,
#  '"jokes"': 567,
#  '"entertainment"': 559,
#  '"science"': 545,
#  '"celebrity"': 542,
#  '"hollywood"': 541,
#  '"podcast"': 536,
#  '"show"': 533,
#  '"movie"': 531,
#  '"game"': 515,
#  '"Entertainment"': 507,
#  '"cooking"': 498,
#  '"animation"': 497,
#  '"family"': 496,
#  '"celebrities"': 495,
#  '"Comedy"': 490,
#  '"funny video"': 487,
#  '"tv"': 483,
#  '"rap"': 482,
#  '"challenge"': 472,
#  '"vlog"': 468,
#  '"best"': 461,
#  '"hilarious"': 457,
#  '"fun"': 456,
#  '"clip"': 450,
#  '"Politics"': 448,
#  '"trailer"': 446,
#  '"movies"': 445,
#  '"new"': 444,
#  '"kids"': 436,
#  '"drama"': 423,
#  '"Funny"': 421,
#  '"NBC"': 417,
#  '"hip hop"': 415,
#  '"Trump"': 413,
#  '"highlights"': 396,
#  '"late night"': 387,
#  '"top 10"': 383,
#  '"breaking news"': 382,
#  '"Drama"': 377,
#  '"nba"': 370,
#  '"fine brothers entertainment"': 366,
#  '"fine brothers"': 364,
#  '"thefinebros"': 361,
#  '"sketch"': 359,
#  '"FBE"': 353,
#  '"Canada"': 351,
#  '"games"': 350,
#  '"live"': 340,
#  '"recipe"': 336,
#  '"humour"': 336,
#  '"official"': 336,
#  '"chef"': 336,
#  '"film"': 336,
#  '"investigation"': 333,
#  '"tutorial"': 329,
#  '"CNN"': 327,
#  '"joke"': 323,
#  '"diy"': 318,
#  '"unboxing"': 317,
#  '"satire"': 317,
#  '"kid friendly"': 316,
#  '"watch"': 314,
#  '"famous"': 313,
#  '"music video"': 311,
#  '"Rap"': 304,
#  '"youtube"': 304,
#  '"Trailer"': 304,
#  '"logan paul"': 302,
#  '"CBS"': 296,
#  '"technology"': 295,
#  '"kitchen"': 295,
#  '"meme"': 293,
#  '"love"': 291,
#  '"parody"': 290,
#  '"sp:vl=en-US"': 289,
#  '"NBC TV"': 287,
#  '"viral"': 287,
#  '"Pop"': 286,
#  '"comedic"': 286,
#  '"gaming"': 284,
#  '"gameplay"': 284,
#  '"celeb"': 284,
#  '"vs"': 278,
#  '"christmas"': 277,
#  '"kids react"': 276,
#  '"police"': 276,
#  '"makeup"': 276,
#  '"celebrity news"': 276,
#  '"conspiracy"': 275,
#  '"beauty"': 275,
#  '"punjabi songs"': 275,
#  '"nba highlights"': 275,
#  '"host"': 274,
#  '"try not to laugh"': 273,
#  '"elders react"': 272,
#  '"promo"': 271,
#  '"reviews"': 270,
#  '"sp:ty=high"': 267,
#  '"teens react"': 266,
#  '"compilation"': 265,
#  '"fine bros"': 261,
#  '"punjabi music"': 257,
#  'rhett and link': 257,
#  '"Stephen Colbert"': 252,
#  '"talk"': 251,
#  '"latest punjabi songs 2018"': 251,
#  '"current events"': 249,
#  '"fashion"': 249,
#  '"punjabi"': 248,
#  '"laugh"': 248,
#  'nba': 248,
#  '"fail"': 247,
#  '"Music"': 247,
#  '"travel"': 246,
#  '"president trump"': 245,
#  '"finebros"': 243,
#  '"DIY"': 243,
#  '"instagram"': 242,
#  '"game highlights"': 240,
#  '"reactions"': 239,
#  '"india"': 239,
#  '"jake paul"': 236,
#  '"animated"': 233,
#  '"space"': 233,
#  '"cleveland cavaliers"': 232,
#  '"memes"': 231,
#  '"talent"': 229,
#  '"play"': 229,
#  '"highlight"': 228,
#  '"us news"': 227,
#  '"liberal"': 226,
#  '"Television"': 224,
#  'BuzzFeed': 224,
#  '"education"': 223,
#  '"rhett"': 222,
#  '"cavaliers"': 222,
#  '"link"': 221,
#  '"TV"': 221,
#  '"mythical"': 218,
#  '"crazy"': 218,
#  '"facebook"': 218,
#  '"daily"': 217,
#  '"Colbert"': 217,
#  '"challenges"': 216,
#  '"cook"': 215,
#  '"murder"': 214,
#  '"reddit"': 214,
#  '"tricks"': 214,
#  '"Gordon Ramsay"': 214,
#  '"amazing"': 212,
#  'Gordon': 212,
#  '"health"': 212,
#  '"h3h3"': 211,
#  '"world"': 211,
#  '"future"': 211,
#  '"punjabi latest songs"': 210,
#  '"disney"': 209,
#  '"MSNBC"': 208,
#  '"lol"': 208,
#  '"Ramsay"': 208,
#  '"lebron james"': 207,
#  '"Ramsey"': 207,
#  '"for the first time"': 207,
#  '"paul"': 205,
#  '"latest punjabi songs"': 205,
#  '"mystery"': 205,
#  '"snl"': 204,
#  '"internet"': 204,
#  '"plays"': 202,
#  '"Tutorial"': 202,
#  '"daytime"': 202,
#  '"animals"': 202,
#  '"fails"': 201,
#  '"football"': 201,
#  '"cute"': 201,
#  '"awards"': 201,
#  '"battle"': 201,
#  '"women"': 199,
#  '"Chef Ramsay"': 199,
#  '"adventure"': 198,
#  '"culture"': 198,
#  '"Late Late Show"': 197,
#  '"videos"': 197,
#  '"video games"': 194,
#  '"top 5"': 194,
#  '"Corden"': 194,
#  '"James Corden"': 194,
#  '"President Trump"': 194,
#  '"scary"': 193,
#  '"learn"': 193,
#  '"crime patrol"': 192,
#  '"h3h3productions"': 191,
#  '"world news"': 191,
#  '"makeup tutorial"': 191,
#  '"youtubers react"': 190,
#  '"setindia"': 190,
#  '"sony tv"': 189,
#  '"dial 100"': 189,
#  'true events': 188,
#  '"crimes against women"': 188,
#  '"indian television"': 188,
#  '"anoop soni"': 188,
#  '"hindi crime serials"': 188,
#  '"Talk Show"': 188,
#  '"iphone"': 187,
#  '"The Young Turks"': 187,
#  '"to"': 187,
#  '"radio"': 187,
#  '"girls"': 186,
#  '"responds"': 186,
#  'NBA': 186,
#  '"tips"': 185,
#  '"house"': 185,
#  '"crimes in india"': 184,
#  '"season"': 184,
#  '"song"': 184,
#  '"anup soni"': 183,
#  '"murder case"': 183,
#  '"weird"': 183,
#  '"respond"': 183,
#  '"logan"': 182,
#  '"lyric breakdown"': 182,
#  '"sony entertainment channel"': 182,
#  '"crime patrol diall 100"': 182,
#  '"desi"': 181,
#  '"how to make"': 181,
#  '"do they know it"': 181,
#  '"parents react"': 181,
#  '"comics"': 180,
#  '"laugh challenge"': 180,
#  '"crime patrol latest episode"': 180,
#  'ABS-CBN': 180,
#  '"adults react"': 179,
#  '"dance"': 179,
#  '"sketch comedy"': 179,
#  '"complex"': 179,
#  '"CBC"': 178,
#  '"the"': 178,
#  '"test"': 178,
#  '"marvel"': 178,
#  '"try"': 177,
#  '"TYT"': 177,
#  '"no swearing"': 177,
#  '"mma"': 176,
#  '"competition"': 176,
#  '"earth"': 176,
#  '"Late Show"': 175,
#  '"nerf"': 175,
#  '"good mythical morning"': 174,
#  'The Late Show': 174,
#  '"HD"': 174,
#  '"james"': 174,
#  '"exclusive"': 174,
#  '"kids versus food"': 173,
#  '"staff reacts"': 173,
#  '"Records"': 173,
#  '"mlg"': 173,
#  '"experiment"': 173,
#  '"UFC"': 172,
#  '"cavs"': 172,
#  '"punjabi romantic songs"': 171,
#  '"lyrics"': 171,
#  '"vlogs"': 171,
#  '"creepy"': 171,
#  '"business"': 171,
#  '"Highlights"': 171,
#  '"10"': 170,
#  '"complex media"': 170,
#  '"Food"': 170,
#  '"prank"': 169,
#  '"canada"': 169,
#  '"monologue"': 169,
#  '"cool"': 168,
#  'Vaani rani': 168,
#  '"rani"': 168,
#  '"Radhika in funny character"': 168,
#  '"venu aravind"': 168,
#  '"SunTV"': 168,
#  '"VaniRani"': 168,
#  '"vani"': 168,
#  '"vaani"': 168,
#  '"Radhika\'s dual role serial"': 168,
#  '"Ranimma veetu kuripu"': 168,
#  '"Radhika as lawyer in serial"': 168,
#  '"radikaa"': 168,
#  '"Radhika\'s new"': 168,
#  '"facts"': 168,
#  '"edgy"': 168,
#  '"ocean"': 168,
#  '"taste test"': 168,
#  '"dank memes"': 168,
#  '"dank"': 168,
#  '"react gaming"': 167,
#  '"tv serial"': 167,
#  '"stand up"': 167,
#  '"youtube news"': 166,
#  '"street food"': 166,
#  '"Cenk Uygur"': 166,
#  '"trending"': 166,
#  '"mythical morning"': 165,
#  '"matpat"': 165,
#  '"stand-up"': 165,
#  '"the ellen show"': 165,
#  '"dank meme compilation"': 165,
#  '"Liberal"': 164,
#  '"dank memes compilation"': 164,
#  '"skits"': 163,
#  '"cosmetics"': 163,
#  '"avengers"': 163,
#  '"no cursing"': 163,
#  '"golden state warriors"': 162,
#  '"pop"': 162,
#  '"philip defranco"': 162,
#  '"ellen degeneres"': 162,
#  '"funny vines"': 162,
#  '"IPC section"': 161,
#  '"cartoon"': 161,
#  '"warriors"': 161,
#  '"meme compilation"': 161,
#  'latest News': 161,
#  '"Happening Now"': 161,
#  '"fortnite"': 161,
#  '"foodie"': 160,
#  '"reacts"': 159,
#  '"top"': 159,
#  '"fresh memes"': 159,
#  '"punjab"': 158,
#  '"seth"': 158,
#  '"gordon"': 158,
#  '"best memes"': 158,
#  '"dank compilation"': 158,
#  '"infinity war"': 158,
#  '"BuzzFeed"': 157,
#  '"the philip defranco show"': 157,
#  '"Pakistan"': 156,
#  '"philip defranco show"': 156,
#  '"dj envy"': 156,
#  '"documentary"': 155,
#  '"charlamagne tha god"': 155,
#  '"weekend update"': 154,
#  '"sxephil"': 154,
#  '"dank meme"': 154,
#  '"RT"': 153,
#  '"gmm"': 153,
#  '"crime"': 153,
#  '"apple"': 153,
#  '"latest"': 153,
#  '"twitter"': 152,
#  '"full episodes"': 152,
#  '"vlogger"': 152,
#  '"bottle flip"': 152,
#  '"shots"': 151,
#  'Collegehumor': 151,
#  '"CH originals"': 151,
#  '"alien"': 151,
#  '"reality"': 151,
#  '"cowbelly comment awards"': 151,
#  '"funniest"': 150,
#  '"subreddit"': 150,
#  '"news satire"': 150,
#  '"walkthrough"': 150,
#  '"funny meme"': 150,
#  '"pg"': 149,
#  '"DeFranco"': 149,
#  'the breakfast club': 149,
#  '"power1051"': 149,
#  '"angela yee"': 149,
#  '"drake"': 149,
#  '"dankest"': 149,
#  '"memes compilation"': 149,
#  '"songs"': 148,
#  '"snl seth meyers"': 148,
#  '"meyers"': 148,
#  '"lebron"': 148,
#  '"rhett and link good mythical morning"': 147,
#  '"good mythical morning rhett and link"': 147,
#  '"channel"': 147,
#  '"vine"': 147,
#  '"action"': 147,
#  '"everything wrong with"': 147,
#  '"Official"': 147,
#  '"tonight"': 147,
#  '"lifehacks"': 147,
#  '"team edge"': 147,
#  '"crafts"': 146,
#  '"team edge challenge"': 146,
#  '"ellen audience"': 146,
#  '"aliens"': 146,
#  '"funny memes"': 146,
#  '"new memes"': 146,
#  '"brazil"': 145,
#  '"ethan and hila"': 145,
#  '"variety"': 145,
#  '"theatre"': 145,
#  '"fox sports"': 145,
#  '"sab tv serials"': 145,
#  '"useful things"': 144,
#  '"trick shots"': 144,
#  'sab tv channel': 144,
#  '"comedy channel india"': 144,
#  '"school"': 143,
#  'jimmy': 143,
#  '"lifestyle"': 143,
#  '"teamedge"': 143,
#  '"fs1"': 143,
#  '"universe"': 143,
#  '"star"': 142,
#  '"russia"': 142,
#  '"progressive"': 142,
#  '"GOP"': 142,
#  '"time"': 142,
#  '"taarak mehta ka ooltah chashmah"': 142,
#  '"jethalal"': 142,
#  '"cowbelly"': 141,
#  '"dankest memes"': 141,
#  '"tappu sena"': 141,
#  '"Taarak Mehta"': 141,
#  '"Daya"': 141,
#  '"Champaklal"': 141,
#  '"Atmaram Bhide"': 141,
#  '"Hansraj Hathi"': 141,
#  '"babita"': 141,
#  '"Gokuldham society"': 141,
#  '"jethalal comedy"': 141,
#  '"taarak mehta full"': 141,
#  '"graham the christian"': 141,
#  '"hannahstocking"': 140,
#  '"anitta"': 140,
#  '"pop culture"': 140,
#  '"lelepons"': 139,
#  '"rudymancuso"': 139,
#  '"alesso"': 139,
#  '"actor"': 139,
#  '"mistakes"': 139,
#  '"comedy sketches"': 139,
#  '"Fallon Stand-up"': 139,
#  '"inanna"': 138,
#  '"anwar"': 138,
#  '"friendly"': 138,
#  '"try to watch without laughing or grinning"': 138,
#  '"new punjabi songs"': 138,
#  '"eww"': 138,
#  '"cinemasins"': 138,
#  '"cinema sins"': 138,
#  '"fox sports 1"': 138,
#  '"media"': 138,
#  '"moon"': 138,
#  '"तारक मेहता"': 138,
#  '"shotsstudios"': 137,
#  '"fail compilation"': 137,
#  '"impressions"': 137,
#  '"Fallon monologue"': 137,
#  '"dr phil"': 137,
#  '"sarkis"': 136,
#  '"list"': 136,
#  '"black panther"': 136,
#  '"fox"': 136,
#  '"history"': 135,
#  '"video game"': 135,
#  '"Jimmy Fallon"': 135,
#  '"ufo"': 135,
#  '"dank memes 2017"': 135,
#  '"hot topics"': 134,
#  '"family games"': 134,
#  '"ellentube"': 134,
#  '"episode"': 134,
#  '"sp:st=icehockey"': 133,
#  '"sp:li=NHL"': 133,
#  '"The Late Late Show"': 133,
#  '"hot"': 132,
#  '"Toronto"': 132,
#  'the real': 132,
#  '"tamera mowry"': 132,
#  '"adrienne bailon"': 132,
#  '"loni love"': 132,
#  '"jeannie mai"': 132,
#  '"NHL"': 132,
#  '"Interview"': 132,
#  '"vox"': 131,
#  '"wrestling"': 131,
#  '"ellen fans"': 131,
#  '"Fox News"': 131,
#  '"NASA"': 131,
#  '"Makeup"': 131,
#  '"food porn"': 131,
#  '"kek"': 131,
#  '"Hop"': 131,
#  '"texas"': 130,
#  '"trevor noah"': 130,
#  'espn': 130,
#  '"ellen tickets"': 130,
#  '"fight"': 130,
#  '"high profile case"': 130,
#  '"money"': 129,
#  '"iphone x"': 129,
#  '"Love"': 129,
#  '"smith"': 129,
#  '"hockey"': 129,
#  '"girlfriend"': 128,
#  '"explain"': 128,
#  '"Vice Ganda"': 128,
#  '"jethalal gada"': 128,
#  '"punjabi songs 2018"': 128,
#  '"Philippines"': 127,
#  '"strange"': 127,
#  '"Hip"': 127,
#  '"comedy videos"': 127,
#  '"edgy memes"': 127,
#  '"new punjabi songs 2018"': 127,
#  '"punjabi bhangra"': 126,
#  '"logang"': 126,
#  '"improv"': 126,
#  '"Russia"': 126,
#  '"ABS-CBN Philippines"': 126,
#  '"ARY"': 126,
#  '"reacting"': 126,
#  '"new dank memes"': 126,
#  '"crimes agaiinst women"': 126,
#  '"cnn"': 125,
#  '"espn live"': 125,
#  '"Kitchen Nightmares"': 125,
#  '"Hotel Hell"': 125,
#  '"skit"': 124,
#  'The Tonight Show': 124,
#  '"boyfriend"': 123,
#  '"gmm food"': 123,
#  'Joe Rogan Experience': 123,
#  '"kids games"': 123,
#  '"cocktail"': 123,
#  '"freestyle"': 123,
#  '"comedy channel hindi"': 123,
#  '"Breaking News"': 123,
#  '"speed records"': 122,
#  '"austin"': 122,
#  '"day"': 122,
#  '"team"': 122,
#  '"fails compilation"': 122,
#  '"the daily show"': 122,
#  '"planet"': 122,
#  '"fwf"': 122,
#  '"firstwefeast"': 122,
#  '"production"': 121,
#  '"epic fails"': 121,
#  '"funny fails"': 121,
#  'hkayet tounsia': 121,
#  '"elhiwar ettounsi"': 121,
#  '"denya okhra"': 121,
#  '"oumour jedia"': 121,
#  '"karim el gharbi"': 121,
#  '"lakers"': 121,
#  '"chicken"': 121,
#  '"white house"': 121,
#  '"keemstar"': 120,
#  '"wow"': 120,
#  '"Hollywood"': 120,
#  '"doug demuro"': 120,
#  '"Animation"': 120,
#  'comedy central': 120,
#  '"comedy central uk"': 120,
#  '"water"': 120,
#  '"TYT Network"': 120,
#  '"Republican"': 120,
#  '"ARY Digital"': 120,
#  '"sab tv live"': 120,
#  '"sab tv new show 2016"': 120,
#  'best vines 2018': 120,
#  '"funniest videos 2018"': 120,
#  '"cheap"': 119,
#  '"simon cowell"': 119,
#  '"andi mankolek"': 119,
#  '"oumour jeddya"': 119,
#  '"dari deco"': 119,
#  '"360 degrees"': 119,
#  '"klem ennes"': 119,
#  '"ma binetna"': 119,
#  '"liman yajroo fakat"': 119,
#  '"labes"': 119,
#  '"labas"': 119,
#  '"awled mofida"': 119,
#  '"maktoub"': 119,
#  '"el hak maak"': 119,
#  '"wled moufida"': 119,
#  '"awled moufida"': 119,
#  '"اليوم الثامن"': 119,
#  '"عندي ما نقلك"': 119,
#  '"مكتوب"': 119,
#  '"أمور جدّية"': 119,
#  '"أولاد مفيده"': 119,
#  'mystery': 119,
#  '"supernatural"': 119,
#  '"audition"': 119,
#  '"punjabi bhangra music"': 118,
#  '"Film"': 118,
#  '"tech"': 118,
#  '"conservative"': 118,
#  '"wrestler"': 118,
#  '"happy nes"': 118,
#  '"antarctica"': 118,
#  '"craft beer"': 118,
#  '"toronto"': 118,
#  '"gadgets"': 117,
#  '"youtuber"': 117,
#  '"Joe Rogan"': 117,
#  '"priyamanaval serial"': 117,
#  '"piriyamanaval"': 117,
#  '"பிரியமானவள்"': 117,
#  '"priyamanaval episode"': 117,
#  '"periyamanaval"': 117,
#  '電視劇': 116,
#  '"大陸電視劇"': 116,
#  '"bhangra"': 116,
#  '"rathika"': 116,
#  '"life"': 116,
#  '"divertissement"': 116,
#  '"Marvel"': 116,
#  '"Best"': 116,
#  '"White House"': 116,
#  '"Cook (Profession)sean evans"': 116,
#  '"web series"': 115,
#  '"fail compilation 2017"': 115,
#  '"kevin durant"': 115,
#  '"secureteam10"': 115,
#  '"Live"': 115,
#  'First we feast': 115,
#  '"punjabi sad songs"': 114,
#  '"top10"': 114,
#  '"fails of the week"': 114,
#  '"political humour"': 114,
#  '"Do it yourself"': 114,
#  '"DIY projects"': 114,
#  '"Handcraft"': 114,
#  '"how"': 114,
#  '"cleveland"': 114,
#  '"hiphop"': 114,
#  '"phil"': 114,
#  '"sean evans"': 114,
#  '"bartender"': 114,
#  '"worldstar"': 114,
#  '"fox news"': 114,
#  '"olympics"': 113,
#  '"good mythical more"': 113,
#  '"daily show"': 113,
#  '"jimmy kimmel"': 113,
#  '"people"': 113,
#  'comment': 113,
#  '"rhett and link good mythical more"': 112,
#  '"good mythical more rhett and link"': 112,
#  '"skateboarding"': 112,
#  '"DIY activities"': 112,
#  '"home"': 112,
#  '"ufos"': 112,
#  '"epic"': 112,
#  '"huge"': 111,
#  '"worst"': 111,
#  '"MSNBC news"': 111,
#  '"secret"': 111,
#  '"relationships"': 111,
#  '"japan"': 111,
#  '"world wrestling entertainment"': 111,
#  '"पहलवान"': 111,
#  '"सुपरस्टार"': 111,
#  '"व्यावसायिक कुश्ती"': 111,
#  '"مصارعه"': 111,
#  '"nhar lahad ma hemek fi had"': 111,
#  '"sami fehri"': 111,
#  '"نهار الأحد ما يهمّك في حدّ"': 111,
#  '"نهار الأحد"': 111,
#  '"mars"': 111,
#  '"president"': 111,
#  '"the voice"': 111,
#  '"team 10"': 110,
#  '"filmmaking"': 110,
#  '"fails 2017"': 110,
#  '"phone"': 110,
#  '"Sports"': 110,
#  '"unbox"': 110,
#  '"superstars"': 110,
#  '"amazon"': 110,
#  '"first take"': 110,
#  '"degeneres"': 110,
#  '"teenagers react"': 110,
#  '"us"': 110,
#  'news': 109,
#  '"NBA"': 109,
#  '"Celebrity"': 109,
#  '"fail army"': 109,
#  '"ABS-CBN Online"': 109,
#  '"Football"': 109,
#  '"android"': 109,
#  '"Hip Hop"': 109,
#  '"Romantic"': 109,
#  '"comment awards"': 109,
#  '"thriller series"': 109,
#  '"superhero"': 108,
#  '"night"': 108,
#  '"MSNBC TV"': 108,
#  '"fail laugh"': 108,
#  '"fails of the month"': 108,
#  '"stephen curry"': 108,
#  '"do it yourself"': 108,
#  '"wrestle"': 108,
#  '"कुश्ती"': 108,
#  '"डब्लू डब्लू ई"': 108,
#  '"मैच"': 108,
#  '"dr."': 108,
#  '"easy"': 108,
#  '"breaking"': 108,
#  '"political news"': 107,
#  '"restaurant"': 107,
#  'wwe': 107,
#  '"Progressive"': 107,
#  '"Democratic"': 107,
#  '"friends"': 107,
#  '"soccer"': 107,
#  '"baby"': 107,
#  '"bhide scooter"': 107,
#  '"MSNBC live"': 106,
#  'failarmy': 106,
#  '"bad friends"': 106,
#  '"scooter fail"': 106,
#  '"failarmy kids"': 106,
#  '"failarmy parkour"': 106,
#  '"failarmy animals"': 106,
#  '"failarmy cats"': 106,
#  '"failarmy instant karma"': 106,
#  '"clean"': 106,
#  '"ovni"': 106,
#  '"Full Game Highlights"': 106,
#  '"Rapid Highlights"': 106,
#  '"seth meyers"': 106,
#  '"top stories"': 106,
#  '"hindi crime drama"': 106,
#  'punjabi songs': 105,
#  '"workout fails"': 105,
#  '"sharpe"': 105,
#  '"kanye west"': 105,
#  '"unsolved"': 105,
#  '"performance"': 105,
#  '"new the daily show"': 105,
#  '"BuzzFeedVideo"': 105,
#  'Rooster Teeth': 104,
#  '"Paul"': 104,
#  '"US news"': 104,
#  '"elections"': 104,
#  '"fail army funny"': 104,
#  '"pets"': 104,
#  '"new york"': 104,
#  '"homemade"': 104,
#  '"undisputed"': 104,
#  '"theory"': 104,
#  '"ghost"': 104,
#  '"trường giang"': 104,
#  '"nhl"': 104,
#  '"robert mueller"': 104,
#  '"rap music"': 104,
#  '"therapy"': 103,
#  '"MMA"': 103,
#  '"random happens"': 103,
#  '"skip bayless"': 103,
#  '"shannon sharpe"': 103,
#  '"skip and shannon"': 103,
#  '"fs1 undisputed"': 103,
#  '"joy taylor"': 103,
#  '"curry"': 103,
#  '"luxury"': 103,
#  '"latest news"': 103,
#  '"worldstarhiphop"': 103,
#  '"Movie"': 103,
#  '"wedding"': 102,
#  '"demuro"': 102,
#  '"trucos de belliza"': 102,
#  '"grant thompson"': 102,
#  '"life hacks"': 102,
#  '"stephen a smith"': 102,
#  '"random"': 102,
#  'fox': 102,
#  '"wshh"': 102,
#  '"Robert Mueller"': 102,
#  '"Nino"': 102,
#  '#DramaAlert': 101,
#  '"Alert"': 101,
#  '"DramaAlert"': 101,
#  '"politics news"': 101,
#  '"make"': 101,
#  '"late night show"': 101,
#  '"eating"': 101,
#  '"the wendy williams show"': 101,
#  '"série"': 101,
#  '"shannon"': 101,
#  '"egoraptor"': 101,
#  '"danny"': 101,
#  '"gamegrumps"': 101,
#  '"film theory"': 101,
#  '"fake news"': 101,
#  '"daily show episodes"': 101,
#  '"Season 13"': 101,
#  '"unbox therapy"': 100,
#  '"#youtubeblack"': 100,
#  '"bayless"': 100,
#  'lets': 100,
#  '"ksi"': 100,
#  '"Showbiz"': 100,
#  '"kid"': 100,
#  '"star wars"': 100,
#  '"fresh"': 100,
#  '"unexplained"': 99,
#  '"samsung"': 99,
#  '"king of random"': 99,
#  '"singing"': 99,
#  '"latest songs"': 99,
#  '"official trailer"': 99,
#  '"recipes"': 99,
#  '"drugstore"': 99,
#  '"skip"': 99,
#  '"grumps"': 99,
#  '"reacting to"': 99,
#  '"food challenge"': 99,
#  '"learning"': 99,
#  '"memes 2017"': 99,
#  '"lonzo ball"': 99,
#  '"taarak mehta new episode"': 99,
#  '"Review"': 98,
#  '"smartphone"': 98,
#  '"behind the scenes"': 98,
#  '"stephen a. smith"': 98,
#  '"tran thanh"': 98,
#  '"the king of random"': 98,
#  '"monster"': 98,
#  '"Recipe"': 98,
#  '"peterson"': 98,
#  '"comedy show"': 98,
#  '"online"': 97,
#  '"david letterman"': 97,
#  '"style"': 97,
#  '"Hockey"': 97,
#  '"explained"': 97,
#  '"funny moments"': 97,
#  '"محمد صلاح"': 97,
#  '"Pranks"': 97,
#  '"it’s raw"': 97,
#  '"US News"': 97,
#  '"taarak mehta comedy"': 97,
#  '"best comedy show"': 97,
#  '"ufc"': 96,
#  '"help"': 96,
#  '"NBC News"': 96,
#  '"nozman"': 96,
#  '"wled mofida"': 96,
#  '"لا بــــاس"': 96,
#  '"Florida"': 96,
#  '"hip hop music"': 96,
#  '"president donald trump"': 96,
#  '"gordon ramsay"': 96,
#  '"iron man"': 96,
#  '"都市"': 95,
#  '"every"': 95,
#  '"brothers"': 95,
#  '"bit"': 95,
#  '"letterman"': 95,
#  '"iphone 8"': 95,
#  '"proyectos faciles"': 95,
#  '"The"': 95,
#  '"Christmas"': 95,
#  '"educational"': 95,
#  '"bts"': 95,
#  '"Dance"': 95,
#  '"college kids react"': 95,
#  '"funny dank memes"': 95,
#  '"daily show 2017"': 95,
#  '"avengers infinity war"': 95,
#  '"pranks"': 94,
#  '"Obama"': 94,
#  '"grant thompson king of random"': 94,
#  '"boston celtics"': 94,
#  '"coyote"': 94,
#  '"Video"': 94,
#  '"gossip"': 94,
#  '"bollywood"': 94,
#  '"kimmel"': 94,
#  '"crime thriller"': 94,
#  '"apple iphone x"': 93,
#  '"john"': 93,
#  '"trucos"': 93,
#  '"JRE"': 93,
#  'dr nozman': 93,
#  '"stephen"': 93,
#  '"hi5 studios"': 93,
#  '"Cooking"': 93,
#  '"wild"': 93,
#  '"cable"': 93,
#  '"unsolved crimes"': 93,
#  '"مسلسلات رمضان 2018"': 93,
#  'Graham Norton': 92,
#  '"YouTube"': 92,
#  '"New"': 92,
#  '"BuzzFeed Tasty"': 92,
#  '"ending"': 92,
#  '"children"': 92,
#  '"Justin Trudeau"': 92,
#  '"hot ones"': 92,
#  '"cardi b"': 92,
#  '"Disney"': 92,
#  '"Priyamanaval episode today"': 92,
#  '"dog"': 91,
#  '"couple"': 91,
#  '"uberhaxornova"': 91,
#  '"Action"': 91,
#  '"truth"': 91,
#  '"first take today"': 91,
#  'mlg highlights': 91,
#  '"sun"': 91,
#  '"bon appétit"': 91,
#  '"Variety"': 91,
#  '"coyote peterson"': 91,
#  '"asmr"': 91,
#  '"Trending"': 91,
#  '"Hi5 Studios"': 91,
#  '"comment"': 91,
#  '"Priyamanaval today"': 91,
#  '"مسلسلات رمضان"': 91,
#  '"Graham Norton Show Official"': 90,
#  '"haul"': 90,
#  '"nikkietutorials"': 90,
#  '"tvpromosdb"': 90,
#  '"series"': 90,
#  '"tkor"': 90,
#  '"mysteries"': 90,
#  '"breaking trail"': 90,
#  '"real"': 90,
#  '"Family"': 90,
#  '"true crime"': 90,
#  '"news channel"': 90,
#  '"Priyamanaval today Episode"': 90,
#  '"top crime series"': 90,
#  '"buzzfeed"': 89,
#  '"haunted"': 89,
#  '"Slow Motion"': 89,
#  '"honest trailers"': 89,
#  '"thekingofrandom"': 89,
#  'senegal': 89,
#  '"youssou ndour;musique"': 89,
#  '"téléfilm"': 89,
#  'channel awesome': 89,
#  '"nostalgia critic"': 89,
#  '"doug walker"': 89,
#  '"HUM TV"': 89,
#  '"art"': 89,
#  '"gold"': 89,
#  '"chef Ramsay"': 89,
#  '"magic"': 89,
#  '"comic scenes"': 89,
#  '"trap"': 88,
#  '"Leafs"': 88,
#  '"sp:st=basketball"': 88,
#  '"cow chop"': 88,
#  '"justkidding youtube"': 88,
#  '"chocolate"': 88,
#  '"trump news"': 88,
#  '"free"': 88,
#  '"car"': 88,
#  '"movie review"': 88,
#  '"teaser"': 88,
#  '"comedians"': 88,
#  '"raphael chestang"': 88,
#  '"RCA Records Label"': 88,
#  '"family fun"': 88,
#  '"experiments"': 88,
#  '"pop music"': 88,
#  '"nba playoffs"': 88,
#  '"PMLN"': 87,
#  '"PPP"': 87,
#  '"JI"': 87,
#  '"Sindh"': 87,
#  '"recap"': 87,
#  ...}

# %%
## Plot word frequencey graph for top 50 most occuring word
wordsList = []
countList = []
for key,val in sortedDict.items():
    wordsList.append(key)
    countList.append(val)
fig, axs=plt.subplots(figsize=(20,10))
axs.plot(wordsList[:50],countList[:50])
axs.set_xticklabels(wordsList[:50],fontsize=10)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
## Word Cloud of most frequently used Tags
cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(sortedDict)
plt.figure(figsize=(10,10))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <a id="obj1b"></a>
# ### How number of word in Title affect Trending videos!!!

# %%
## Length of title..
titleList = []
for i,row in videoCompleteDF.iterrows():
    titleList.append(len(row["title"].split(" ")))
videoCompleteDF["titleWordCount"] = titleList
sortedVideo = videoCompleteDF.sort_values(by="titleWordCount", ascending=False)

# %%
grouppedVidep = sortedVideo.groupby(by="titleWordCount").count()
grouppedVidep
# Out:
#                 video_id  trending_date  title  channel_title  category_id  \
# titleWordCount
# 1                    497            497    497            497          497
# 2                    460            460    460            460          460
# 3                   1508           1508   1508           1508         1508
# 4                   2202           2202   2202           2202         2202
# 5                   2976           2976   2976           2976         2976
# 6                   3580           3580   3580           3580         3580
# 7                   4104           4104   4104           4104         4104
# 8                   3697           3697   3697           3697         3697
# 9                   3688           3688   3688           3688         3688
# 10                  3436           3436   3436           3436         3436
# 11                  2892           2892   2892           2892         2892
# 12                  2497           2497   2497           2497         2497
# 13                  2070           2070   2070           2070         2070
# 14                  1728           1728   1728           1728         1728
# 15                  1676           1676   1676           1676         1676
# 16                  1245           1245   1245           1245         1245
# 17                  1019           1019   1019           1019         1019
# 18                   695            695    695            695          695
# 19                   386            386    386            386          386
# 20                   232            232    232            232          232
# 21                   153            153    153            153          153
# 22                    68             68     68             68           68
# 23                    49             49     49             49           49
# 24                    11             11     11             11           11
# 25                     8              8      8              8            8
# 26                     1              1      1              1            1
# 28                     2              2      2              2            2
# 30                     1              1      1              1            1
#
#                 publish_time  tags  views  likes  dislikes  comment_count  \
# titleWordCount
# 1                        497   497    497    497       497            497
# 2                        460   460    460    460       460            460
# 3                       1508  1508   1508   1508      1508           1508
# 4                       2202  2202   2202   2202      2202           2202
# 5                       2976  2976   2976   2976      2976           2976
# 6                       3580  3580   3580   3580      3580           3580
# 7                       4104  4104   4104   4104      4104           4104
# 8                       3697  3697   3697   3697      3697           3697
# 9                       3688  3688   3688   3688      3688           3688
# 10                      3436  3436   3436   3436      3436           3436
# 11                      2892  2892   2892   2892      2892           2892
# 12                      2497  2497   2497   2497      2497           2497
# 13                      2070  2070   2070   2070      2070           2070
# 14                      1728  1728   1728   1728      1728           1728
# 15                      1676  1676   1676   1676      1676           1676
# 16                      1245  1245   1245   1245      1245           1245
# 17                      1019  1019   1019   1019      1019           1019
# 18                       695   695    695    695       695            695
# 19                       386   386    386    386       386            386
# 20                       232   232    232    232       232            232
# 21                       153   153    153    153       153            153
# 22                        68    68     68     68        68             68
# 23                        49    49     49     49        49             49
# 24                        11    11     11     11        11             11
# 25                         8     8      8      8         8              8
# 26                         1     1      1      1         1              1
# 28                         2     2      2      2         2              2
# 30                         1     1      1      1         1              1
#
#                 thumbnail_link  comments_disabled  ratings_disabled  \
# titleWordCount
# 1                          497                497               497
# 2                          460                460               460
# 3                         1508               1508              1508
# 4                         2202               2202              2202
# 5                         2976               2976              2976
# 6                         3580               3580              3580
# 7                         4104               4104              4104
# 8                         3697               3697              3697
# 9                         3688               3688              3688
# 10                        3436               3436              3436
# 11                        2892               2892              2892
# 12                        2497               2497              2497
# 13                        2070               2070              2070
# 14                        1728               1728              1728
# 15                        1676               1676              1676
# 16                        1245               1245              1245
# 17                        1019               1019              1019
# 18                         695                695               695
# 19                         386                386               386
# 20                         232                232               232
# 21                         153                153               153
# 22                          68                 68                68
# 23                          49                 49                49
# 24                          11                 11                11
# 25                           8                  8                 8
# 26                           1                  1                 1
# 28                           2                  2                 2
# 30                           1                  1                 1
#
#                 video_error_or_removed  description  category_name
# titleWordCount
# 1                                  497          426            497
# 2                                  460          418            460
# 3                                 1508         1443           1505
# 4                                 2202         2134           2196
# 5                                 2976         2904           2968
# 6                                 3580         3515           3575
# 7                                 4104         4010           4095
# 8                                 3697         3585           3695
# 9                                 3688         3549           3680
# 10                                3436         3296           3431
# 11                                2892         2764           2890
# 12                                2497         2409           2495
# 13                                2070         2006           2066
# 14                                1728         1681           1723
# 15                                1676         1646           1672
# 16                                1245         1216           1243
# 17                                1019         1005           1013
# 18                                 695          678            694
# 19                                 386          384            384
# 20                                 232          230            232
# 21                                 153          150            153
# 22                                  68           64             68
# 23                                  49           49             49
# 24                                  11           11             11
# 25                                   8            8              8
# 26                                   1            1              1
# 28                                   2            2              2
# 30                                   1            1              1

# %%
plt.scatter(grouppedVidep.index,grouppedVidep["video_id"])
plt.xlabel("Word Count in Title")
plt.ylabel("Frequency of title with specific Word Count")
plt.grid()

# %% [markdown]
# <a id="obj1c"></a>
# ### Curious on what to put as description??

# %% [markdown]
# #### Does having links in description helps videos to trend ? If so how many?

# %%
## method to check if text contain link
## if link exist, returns list of links else empty list
def hasLink(text):
    URL_PATTERN = "(http|ftp|https):\/\/([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:\/~+#-]*[\w@?^=%&\/~+#-])"
    return(re.findall(URL_PATTERN,text))

# %%
## Check record which has link in description and how many link per video description
lenLink = []
for i , row in videoCompleteDF.iterrows():
        lenLink.append(len(hasLink(row["description"])))
videoCompleteDF["lenLink"] = lenLink

# %%
## Percent of videos with link in description
lables=["Video with link","Video with no links"]
explode=(0.1,0)
plt.pie([videoCompleteDF[videoCompleteDF["lenLink"]!=0].shape[0],videoCompleteDF[videoCompleteDF["lenLink"]==0].shape[0]],labels=lables,explode=explode,autopct='%1.1f%%',radius=2)
plt.show()

# %%
# average number of links in trending video description
videoCompleteDF["lenLink"].describe()["mean"]
# Out:
# 7.59889872871679

# %%
videoLinkLenDf = videoCompleteDF.groupby("lenLink").count()
videoLinkLenDf=videoLinkLenDf.sort_values("video_id",ascending=False)

explode = [0]*17
explode.insert(0,0.5)
explode.insert(1,0.4)

lables = []
for length in videoLinkLenDf.index[1:20]:
    if length == 0:
        lables.append(str(length)+" link")
    else:
        lables.append(str(length)+" links")
plt.pie(videoLinkLenDf["video_id"][1:20],labels=lables,explode=explode, radius=2,autopct='%1.1f%%')
plt.figure(figsize=(16,20))
plt.show()

# %% [markdown]
# #### Ever thought if trending video is influenced on whether a Eighth grade can understand its description after single read!!

# %%
### readability analisys
videoCompleteDF["textstat"] = videoCompleteDF["description"].apply(textstat.gunning_fog).apply(round)

# %%
videoCompleteDF["textstat"].describe()
# Out:
# count    39409.000000
# mean         8.998427
# std          3.802738
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         20.000000
# Name: textstat, dtype: float64

# %%
videoCompleteDF= videoCompleteDF[videoCompleteDF["textstat"]<=20]
videoCompleteDF.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 5  0yIWz1XEeyc      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 5  Jake Paul Says Alissa Violet CHEATED with LOGA...    DramaAlert
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 5           25  2017-11-13T07:37:51.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828  132239
# 5  #DramaAlert|"Drama"|"Alert"|"DramaAlert"|"keem...   1309699  103755
#
#    dislikes  ...  comments_disabled ratings_disabled  video_error_or_removed  \
# 0     43420  ...              False            False                   False
# 1      1688  ...              False            False                   False
# 2      5339  ...              False            False                   False
# 3      1989  ...              False            False                   False
# 5      4613  ...              False            False                   False
#
#                                          description    category_name  \
# 0  Eminem's new track Walk on Water ft. Beyoncé i...            Music
# 1  STill got a lot of packages. Probably will las...           Comedy
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...           Comedy
# 3  I know it's been a while since we did this sho...    Entertainment
# 5  ► Follow for News! - https://twitter.com/KEEMS...  News & Politics
#
#   titleWordCount lenLink  textstat  desstat  textstatARI
# 0              8      14         7     6.67       -68.87
# 1              6       9         8     8.34       -12.19
# 2             10      19        11    11.05      -143.18
# 3              5       7         9     8.80         3.32
# 5             16      12        10    10.32      -151.84
#
# [5 rows x 22 columns]

# %%
videoCompleteDF["textstat"].describe()
# Out:
# count    39409.000000
# mean         8.998427
# std          3.802738
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         20.000000
# Name: textstat, dtype: float64

# %%
videoTextDf = videoCompleteDF.groupby("textstat").count()
videoTextDf = videoTextDf.sort_values("video_id",ascending=False)
explode = [0]*16
explode.insert(0,0.5)
explode.insert(1,0.5)
explode.insert(2,0.5)
explode.insert(3,0.5)
lables = []
for length in videoTextDf.index[:20]:
        lables.append(str(length)+" Gunning Fog value")
plt.pie(videoLinkLenDf["video_id"][:20],labels=lables,explode=explode, radius=2,autopct='%1.1f%%')
plt.figure(figsize=(16,20))
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot( data=videoCompleteDF["textstat"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Does asking for Like, Subscribe or Share really helps in trending of videos ???

# %%
## call to action method check if Subscribe,Like,Share pattern is seen in text
def callToAction(text):
    CTA_PATTERN = re.compile("(Subscribe|Like|Share|Sharing|shared|Liking|subscribing|subscribed|)",re.IGNORECASE)
    return(re.search(CTA_PATTERN,text).group())

# %%
#Calcualte if call to action in description influence if the video would be trending!
callToActionList = []
for i,row in videoCompleteDF.iterrows():
    match = callToAction(row["description"])
    if match:
        callToActionList.append(match)

# %%
## Percent of videos with link in description
lables=["Video with Call to Action","Video with No Call to Action"]
explode=(0.1,0)
plt.pie([len(callToActionList),videoCompleteDF.shape[0]],labels=lables,explode=explode,autopct='%1.1f%%',radius=2)
plt.show()

# %% [markdown]
# <a id= "obj2"></a>
# ## Objective 2 : Check how engagement metrics are crucial for trending videos!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
videos=pd.read_csv("CAvideos.csv")
# print(videos.head(5))
newvideos=videos[["views","likes","dislikes","comment_count","trending_date","publish_time"]]
newvideos['trending_date'] = pd.to_datetime(newvideos['trending_date'], format='%y.%d.%m')
newvideos['publish_time'] = pd.to_datetime(newvideos['publish_time'])
# for i,k in newvideos.iterrows():
    
#     newvideos.loc[i,"publish_time"]= datetime.strptime(k["publish_time"], "%Y-%m-%dT%H:%M:%S.%fZ")
    
# newvideos[["trending_date","publish_time"]]=newvideos[["trending_date","publish_time"]].astype(float)
# print(newvideos.head(-30))

# %%
# calculate the correlation coefficient
correlation_matrix = newvideos.corr()
correlation_matrix

# %%
#correlation graph

# scatter plots to visualize the correlation between pairs of metrics

# g = pd.plotting.scatter_matrix(newvideos, figsize=(10,10), marker = 'o', hist_kwds = {'bins': 10}, s = 60, alpha = 0.8)
sns.pairplot(newvideos, diag_kws={'bins': 30})

# %%
#correlation matrix using heatmap

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# disabled_com_videos=videos[videos["comments_disabled"]==True]
# disabled_com_videos
# rating_diabled_videos=videos[videos["ratings_disabled"]==True]
# rating_diabled_videos
fig,axs=plt.subplots(1,2,sharey=True)
sns.boxplot(x="comments_disabled",y="views",data=videos,ax=axs[0])
sns.boxplot(x="ratings_disabled",y="views",data=videos,ax=axs[1])
fig.tight_layout()
print(videos[videos["comments_disabled"]==True]["views"].mean())
print(videos["views"].mean())
print(videos[videos["comments_disabled"]==False]["views"].mean())

# print(videos[videos["comments_disabled"]==True]["views"].median())
print(videos[videos["ratings_disabled"]==True]["views"].mean())
print(videos[videos["ratings_disabled"]==False]["views"].mean())

# print(videos[videos["ratings_disabled"]==True]["views"].median())


# print(disabled_com_videos)

# %%
df.shape

# %%
tahtemp =[]
for i, row in df.iterrows():
    tahtemp.append(row["tags"].split("|"))
tahtemp[12]

# %%
## common methods
# what methods does.!!!

# %%
df.groupby(by="publish_time").count().sort_values(by="video_id",ascending=False)

# %%
def getColumnsList(data):
    return [ x for x in data.columns]

# %%
df.info(null_counts=True)

# %%
jsonDF = pd.read_json("../archive/CA_category_id.json")
jsonDF.head()

# %%
jsonDF.shape

# %%
jsonDF["items"][0]

# %%
def getCategoryFromJson(data):
    import json
    category = {}
    for i, row in data.iterrows():
        tempdict = dict(row)
        category[tempdict["items"]["id"]]= tempdict["items"]["snippet"]["title"]
    return category
getCategoryFromJson(jsonDF)

# %%
def appendCategoryToDataFrame(dataFrame,category):
    tempList = []
    for i,row in dataFrame.iterrows():
        if str(row["category_id"]) in category.keys():
            tempList.append(category[str(row["category_id"])])
        else :
            tempList.append(None)
    df["category_name"] = tempList
appendCategoryToDataFrame(df,getCategoryFromJson(jsonDF))
getColumnsList(df)

# %%
df[df["category_name"] == "p"].count()

# %%
category.keys()

# %%
(type(row["category_id"]))

# %%
df.columns

# %% [markdown]
# Objective : Time to trends, and its relation between category

# %%
#import date
from datetime import datetime,timezone
tempDateList = []
for i, row in df.iterrows():
    tempDateList.append(datetime.fromisoformat(row["publish_time"][:-1]).astimezone(timezone.utc).strftime('%Y-%m-%d %H:%M:%S'))
    
df["publishDate"] = tempDateList

# %%
df["publishDate"]

# %%
df["publishDate"] = pd.to_datetime(df["publishDate"])

# %% [markdown]
# time to trend

# %%
#import date
from datetime import datetime,timezone
trendingDate = []
for i, row in df.iterrows():
#     date = datetime.datetime.strptime(day.group(), '%Y-%m-%d').date()
    trendingDate.append((datetime.strptime(row["trending_date"], '%y.%d.%m').strftime('%Y-%m-%d')))

df["trending_date"] = trendingDate
df["trending_date"] = pd.to_datetime(df["trending_date"])

# %%
df["treandingDiff"]=df["trending_date"] - df["publishDate"]

# %%
df.columns

# %%
df.head(10)

# %%
requiredDF = df[["category_id","category_name","treandingDiff"]]
requiredDF

# %%
requiredDF.columns

# %%
requiredDF["treandingDiff"].describe()

# %%
df_gB = df.groupby(by="category_name").count()
df_gB

# %%
df.groupby(by="channel_title").count().sort_values("video_id", ascending=False)

# %%
requiredDF["category_name"]

# %%
# import matplotlib.pyplot as plt
# plt.bar(requiredDF[requiredDF["category_id"] == 1]["category_id"],requiredDF[requiredDF["category_id"] == 1]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 2]["category_id"],requiredDF[requiredDF["category_id"] == 2]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 23]["category_id"],requiredDF[requiredDF["category_id"] == 23]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 24]["category_id"],requiredDF[requiredDF["category_id"] == 24]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 10]["category_id"],requiredDF[requiredDF["category_id"] == 10]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 25]["category_id"],requiredDF[requiredDF["category_id"] == 25]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 22]["category_id"],requiredDF[requiredDF["category_id"] == 22]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 26]["category_id"],requiredDF[requiredDF["category_id"] == 26]["treandingDiff"])
# plt.bar(requiredDF[requiredDF["category_id"] == 28]["category_id"],requiredDF[requiredDF["category_id"] == 28]["treandingDiff"])

# %%
XVal=requiredDF["category_name"].unique()
XVal

# %%
YVal = requiredDF["category_name"].value_counts()
YVal

# %%
plt.bar(XVal,YVal)

# %%
### like to dislike ratio
### view ratio
### View per category

# %%
df["channel_title"].value_counts()[:25]

# %%
df.sort_values("views", ascending=False)

# %%
Factor

# %%
import sklearn.neighbors as skn
from sklearn.model_selection import train_test_split
x = 
X_train, X_test, Y_train, Y_train = train_test_split()

# %%
# # correc the type of tranding_date
# df["trending_date"]=pd.to_datetime(df["trending_date"],format="%y.%d.%m")
# # correct the type of published_time
# df["publish_time"]=pd.to_datetime(df["publish_time"])

# %%
##Object 1 :

# %%
##Object 2 :

# %%
##Object 3 :

# %%
##Object 4 :
